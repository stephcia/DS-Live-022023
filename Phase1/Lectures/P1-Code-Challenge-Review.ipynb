# %% [markdown]
# # Phase 1 Code Challenge Review
#
# ![let's do this](https://media.giphy.com/media/12WPxqBJAwOuIM/giphy.gif)

# %% [markdown]
# The topics covered will be:
#
#   - [Interacting with Pandas dataframes](#dataframes)
#   - [Visualization](#viz)
#   - [Python Data Structures](#datastructures)

# %%
# My function to call on y'all
# from src.call import call_on_students

# %% [markdown]
# <a id='dataframes'></a>
# # Part 1: Interacting with Pandas DataFrames

# %% [markdown]
# To practice working with dataframes, we will use some Facebook data taken from the UCI Machine Learning repository.
#
# Refer to this paper if you are interested in learning more. There is also a nice description of the features: http://www.math-evry.cnrs.fr/_media/members/aguilloux/enseignements/m1mint/moro2016.pdf

# %%
# Before anything else - need to import pandas!
import pandas as pd

# %% [markdown]
# ## Task 1: Read in the data

# %%
# Can explore the data folder within your notebook
# !ls -a ..
# Out:
# .                  .DS_Store          Completed_Lectures Supplment_Practice
# ..                 Assessments        Lectures

# %% [markdown]
# Read 'dataset_Facebook.csv' from the data foldeer into the notebook as a Pandas dataframe.
#
# Note: we'll need to set a different delimiter here - let's read the data in, then explain what that means.

# %%
# call_on_students(1)

# %%
# Your code here
df = pd.read_csv('data/dataset_Facebook.csv', sep=';')

# %% [markdown]
# ## Task 2: Explore the data

# %% [markdown]
# ### 2a: Look at the first five rows of the dataframe, then the last ten rows

# %%
# call_on_students(1)

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
#  7   Lifetime Post Total Reach                                            500 non-null    int64
#  8   Lifetime Post Total Impressions                                      500 non-null    int64
#  9   Lifetime Engaged Users                                               500 non-null    int64
#  10  Lifetime Post Consumers                                              500 non-null    int64
#  11  Lifetime Post Consumptions                                           500 non-null    int64
#  12  Lifetime Post Impressions by people who have liked your Page         500 non-null    int64
#  13  Lifetime Post reach by people who like your Page                     500 non-null    int64
#  14  Lifetime People who have liked your Page and engaged with your post  500 non-null    int64
#  15  comment                                                              500 non-null    int64
#  16  like                                                                 499 non-null    float64
#  17  share                                                                496 non-null    float64
#  18  Total Interactions                                                   500 non-null    int64
# dtypes: float64(3), int64(15), object(1)
# memory usage: 74.3+ KB

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# std      0.448739                22740.78789                     7.680325e+04
# min      0.000000                  238.00000                     5.700000e+02
# 25%      0.000000                 3315.00000                     5.694750e+03
# 50%      0.000000                 5281.00000                     9.051000e+03
# 75%      1.000000                13168.00000                     2.208550e+04
# max      1.000000               180480.00000                     1.110282e+06
#
#        Lifetime Engaged Users  Lifetime Post Consumers  \
# count              500.000000               500.000000
# mean               920.344000               798.772000
# std                985.016636               882.505013
# min                  9.000000                 9.000000
# 25%                393.750000               332.500000
# 50%                625.500000               551.500000
# 75%               1062.000000               955.500000
# max              11452.000000             11328.000000
#
#        Lifetime Post Consumptions  \
# count                  500.000000
# mean                  1415.130000
# std                   2000.594118
# min                      9.000000
# 25%                    509.250000
# 50%                    851.000000
# 75%                   1463.000000
# max                  19779.000000
#
#        Lifetime Post Impressions by people who have liked your Page  \
# count                                       5.000000e+02
# mean                                        1.676638e+04
# std                                         5.979102e+04
# min                                         5.670000e+02
# 25%                                         3.969750e+03
# 50%                                         6.255500e+03
# 75%                                         1.486050e+04
# max                                         1.107833e+06
#
#        Lifetime Post reach by people who like your Page  \
# count                                        500.000000
# mean                                        6585.488000
# std                                         7682.009405
# min                                          236.000000
# 25%                                         2181.500000
# 50%                                         3417.000000
# 75%                                         7989.000000
# max                                        51456.000000
#
#        Lifetime People who have liked your Page and engaged with your post  \
# count                                         500.000000
# mean                                          609.986000
# std                                           612.725618
# min                                             9.000000
# 25%                                           291.000000
# 50%                                           412.000000
# 75%                                           656.250000
# max                                          4376.000000
#
#          comment         like       share  Total Interactions
# count  500.00000   499.000000  496.000000          500.000000
# mean     7.48200   177.945892   27.266129          212.120000
# std     21.18091   323.398742   42.613292          380.233118
# min      0.00000     0.000000    0.000000            0.000000
# 25%      1.00000    56.500000   10.000000           71.000000
# 50%      3.00000   101.000000   19.000000          123.500000
# 75%      7.00000   187.500000   32.250000          228.500000
# max    372.00000  5172.000000  790.000000         6334.000000

# %% [markdown]
# ### 2b: Look at the information for each column in the dataframe, then describe what you notice

# %%
# call_on_students(1)

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
#  7   Lifetime Post Total Reach                                            500 non-null    int64
#  8   Lifetime Post Total Impressions                                      500 non-null    int64
#  9   Lifetime Engaged Users                                               500 non-null    int64
#  10  Lifetime Post Consumers                                              500 non-null    int64
#  11  Lifetime Post Consumptions                                           500 non-null    int64
#  12  Lifetime Post Impressions by people who have liked your Page         500 non-null    int64
#  13  Lifetime Post reach by people who like your Page                     500 non-null    int64
#  14  Lifetime People who have liked your Page and engaged with your post  500 non-null    int64
#  15  comment                                                              500 non-null    int64
#  16  like                                                                 499 non-null    float64
#  17  share                                                                496 non-null    float64
#  18  Total Interactions                                                   500 non-null    int64
# dtypes: float64(3), int64(15), object(1)
# memory usage: 74.3+ KB

# %% [markdown]
# What do you notice?
#
# - 500 rows
# - 19 columns
# - paid, like, and share are missing one - very small amount of null values
# - paid is boolean (1 or 0)

# %% [markdown]
# ### 2c: Describe the dataframe's numeric columns, then describe what you notice

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# std      0.448739                22740.78789                     7.680325e+04
# min      0.000000                  238.00000                     5.700000e+02
# 25%      0.000000                 3315.00000                     5.694750e+03
# 50%      0.000000                 5281.00000                     9.051000e+03
# 75%      1.000000                13168.00000                     2.208550e+04
# max      1.000000               180480.00000                     1.110282e+06
#
#        Lifetime Engaged Users  Lifetime Post Consumers  \
# count              500.000000               500.000000
# mean               920.344000               798.772000
# std                985.016636               882.505013
# min                  9.000000                 9.000000
# 25%                393.750000               332.500000
# 50%                625.500000               551.500000
# 75%               1062.000000               955.500000
# max              11452.000000             11328.000000
#
#        Lifetime Post Consumptions  \
# count                  500.000000
# mean                  1415.130000
# std                   2000.594118
# min                      9.000000
# 25%                    509.250000
# 50%                    851.000000
# 75%                   1463.000000
# max                  19779.000000
#
#        Lifetime Post Impressions by people who have liked your Page  \
# count                                       5.000000e+02
# mean                                        1.676638e+04
# std                                         5.979102e+04
# min                                         5.670000e+02
# 25%                                         3.969750e+03
# 50%                                         6.255500e+03
# 75%                                         1.486050e+04
# max                                         1.107833e+06
#
#        Lifetime Post reach by people who like your Page  \
# count                                        500.000000
# mean                                        6585.488000
# std                                         7682.009405
# min                                          236.000000
# 25%                                         2181.500000
# 50%                                         3417.000000
# 75%                                         7989.000000
# max                                        51456.000000
#
#        Lifetime People who have liked your Page and engaged with your post  \
# count                                         500.000000
# mean                                          609.986000
# std                                           612.725618
# min                                             9.000000
# 25%                                           291.000000
# 50%                                           412.000000
# 75%                                           656.250000
# max                                          4376.000000
#
#          comment         like       share  Total Interactions
# count  500.00000   499.000000  496.000000          500.000000
# mean     7.48200   177.945892   27.266129          212.120000
# std     21.18091   323.398742   42.613292          380.233118
# min      0.00000     0.000000    0.000000            0.000000
# 25%      1.00000    56.500000   10.000000           71.000000
# 50%      3.00000   101.000000   19.000000          123.500000
# 75%      7.00000   187.500000   32.250000          228.500000
# max    372.00000  5172.000000  790.000000         6334.000000

# %%
# call_on_students(1)

# %% [markdown]
# Your code here
#
# - Paid should not be float - it should be boolean
# - Like and share

# %% [markdown]
# What do you notice?
#
# -

# %% [markdown]
# ## Task 3: Explore null values

# %% [markdown]
# ### 3a: Count how many null values there are in each column

# %%
# call_on_students(1)

# %%
# Your code here
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# Lifetime Post reach by people who like your Page                       0
# Lifetime People who have liked your Page and engaged with your post    0
# comment                                                                0
# like                                                                   1
# share                                                                  4
# Total Interactions                                                     0
# dtype: int64

# %% [markdown]
# ### 3b: What are some of the things we could do to deal with null values?

# %%
# call_on_students(1)

# %% [markdown]
# Answer:
#
# - drop nulls, depending on how many
#     - drop the row itself
#     - drop the columns that have nulls
# - missing indicator with boolean (yes, no)
# - fill in with some measure of central tendency
# - fill in with a new category ('Unknown or N/A')

# %% [markdown]
# ### 3c: Drop records that have null values in the `share` column

# %%
# call_on_students(1)

# %%
# Your code here

df.dropna(subset=['share'], inplace=True)

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# Lifetime Post reach by people who like your Page                       0
# Lifetime People who have liked your Page and engaged with your post    0
# comment                                                                0
# like                                                                   0
# share                                                                  0
# Total Interactions                                                     0
# dtype: int64

# %% [markdown]
# ## Task 4: Create a column

# %% [markdown]
# An "impression" counts each time a post is displayed.
#
# Create a new column called `likes_per_impression` which divides the number of likes per post by the number of impressions per post.

# %%
# call_on_students(1)

# %%
# Your code here

df['likes_per_impression'] = df['like'] / df['Lifetime Post Total Impressions']

# %%
likes_per_impression
# Out:
# 0      0.015518
# 1      0.006822
# 2      0.015093
# 3      0.017865
# 4      0.023908
#          ...
# 495    0.007033
# 496    0.008509
# 497    0.012888
# 498    0.012031
# 499    0.012479
# Length: 496, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 496 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     496 non-null    int64
#  1   Type                                                                 496 non-null    object
#  2   Category                                                             496 non-null    int64
#  3   Post Month                                                           496 non-null    int64
#  4   Post Weekday                                                         496 non-null    int64
#  5   Post Hour                                                            496 non-null    int64
#  6   Paid                                                                 495 non-null    float64
#  7   Lifetime Post Total Reach                                            496 non-null    int64
#  8   Lifetime Post Total Impressions                                      496 non-null    int64
#  9   Lifetime Engaged Users                                               496 non-null    int64
#  10  Lifetime Post Consumers                                              496 non-null    int64
#  11  Lifetime Post Consumptions                                           496 non-null    int64
#  12  Lifetime Post Impressions by people who have liked your Page         496 non-null    int64
#  13  Lifetime Post reach by people who like your Page                     496 non-null    int64
#  14  Lifetime People who have liked your Page and engaged with your post  496 non-null    int64
#  15  comment                                                              496 non-null    int64
#  16  like                                                                 496 non-null    float64
#  17  share                                                                496 non-null    float64
#  18  Total Interactions                                                   496 non-null    int64
#  19  likes_per_impression                                                 496 non-null    float64
# dtypes: float64(4), int64(15), object(1)
# memory usage: 81.4+ KB

# %% [markdown]
# ## Task 5: Multiply `likes_per_impression` by 100 so they look like percentages

# %% [markdown]
# Make a new column for this, `likes_per_impression_perc`, to capture this output.

# %%
# call_on_students(1)

# %%
# Your code here
df['likes_per_impression_perc'] = df['likes_per_impression'] * 100

# %%
df['likes_per_impression_perc']
# Out:
# 0      1.551758
# 1      0.682164
# 2      1.509261
# 3      1.786546
# 4      2.390761
#          ...
# 495    0.703291
# 496    0.850859
# 497    1.288803
# 498    1.203067
# 499    1.247943
# Name: likes_per_impression_perc, Length: 496, dtype: float64

# %% [markdown]
# ## Task 6: How many examples of each type of post?

# %% [markdown]
# I'm seeing a lot of posts with the type of 'Photo' - are there other post types, and what's the breakdown?

# %%
# call_on_students(1)

# %%
# Your code here
df['Type'].value_counts()
# Out:
# Photo     422
# Status     45
# Link       22
# Video       7
# Name: Type, dtype: int64

# %%
# Can also look at the percentages
df['Type'].value_counts(normalize=True)
# Out:
# Photo     0.850806
# Status    0.090726
# Link      0.044355
# Video     0.014113
# Name: Type, dtype: float64

# %% [markdown]
# ## Task 7: Find the five Photos with the highest likes/impression ratio

# %% [markdown]
# Find the five **Photos** with the highest number in our new `likes_per_impression_perc` column

# %%
# call_on_students(1)

# %%
top_5 = df.loc[df['Type'] == "Photo"].sort_values(by='likes_per_impression_perc',
                                                      ascending=False).head()
top_5
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 476             86909  Photo         1           1             6         10
# 87             137177  Photo         3          11             3         10
# 161            135617  Photo         2           9             7          3
# 81             137177  Photo         3          11             6         10
# 92             137059  Photo         3          11             1          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 476   1.0                      37088                            10966
# 87    0.0                       4012                             7955
# 161   0.0                       3992                             7255
# 81    0.0                       5990                            11123
# 92    0.0                       4732                             9303
#
#      Lifetime Engaged Users  ...  Lifetime Post Consumptions  \
# 476                    2728  ...                        3183
# 87                      550  ...                         477
# 161                     598  ...                         688
# 81                      657  ...                         512
# 92                      607  ...                         518
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 476                                              66311
# 87                                                4625
# 161                                               4428
# 81                                                5057
# 92                                                6201
#
#      Lifetime Post reach by people who like your Page  \
# 476                                             34352
# 87                                               2218
# 161                                              2420
# 81                                               2628
# 92                                               3136
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 476                                               2021
# 87                                                 403
# 161                                                435
# 81                                                 428
# 92                                                 445
#
#      comment   like  share  Total Interactions  likes_per_impression  \
# 476        7  579.0   47.0                 633              0.052800
# 87         3  270.0   38.0                 311              0.033941
# 161        6  244.0   32.0                 282              0.033632
# 81        18  370.0   53.0                 441              0.033264
# 92         9  301.0   32.0                 342              0.032355
#
#      likes_per_impression_perc
# 476                   5.279956
# 87                    3.394092
# 161                   3.363198
# 81                    3.326441
# 92                    3.235515
#
# [5 rows x 21 columns]

# %%
top_5
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 476             86909  Photo         1           1             6         10
# 87             137177  Photo         3          11             3         10
# 161            135617  Photo         2           9             7          3
# 81             137177  Photo         3          11             6         10
# 92             137059  Photo         3          11             1          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 476   1.0                      37088                            10966
# 87    0.0                       4012                             7955
# 161   0.0                       3992                             7255
# 81    0.0                       5990                            11123
# 92    0.0                       4732                             9303
#
#      Lifetime Engaged Users  ...  Lifetime Post Consumptions  \
# 476                    2728  ...                        3183
# 87                      550  ...                         477
# 161                     598  ...                         688
# 81                      657  ...                         512
# 92                      607  ...                         518
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 476                                              66311
# 87                                                4625
# 161                                               4428
# 81                                                5057
# 92                                                6201
#
#      Lifetime Post reach by people who like your Page  \
# 476                                             34352
# 87                                               2218
# 161                                              2420
# 81                                               2628
# 92                                               3136
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 476                                               2021
# 87                                                 403
# 161                                                435
# 81                                                 428
# 92                                                 445
#
#      comment   like  share  Total Interactions  likes_per_impression  \
# 476        7  579.0   47.0                 633              0.052800
# 87         3  270.0   38.0                 311              0.033941
# 161        6  244.0   32.0                 282              0.033632
# 81        18  370.0   53.0                 441              0.033264
# 92         9  301.0   32.0                 342              0.032355
#
#      likes_per_impression_perc
# 476                   5.279956
# 87                    3.394092
# 161                   3.363198
# 81                    3.326441
# 92                    3.235515
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Task 8: Find the most liked Photo

# %% [markdown]
# Locate the **Photo** that has the largest amount of likes in the `like` column

# %%
# call_on_students(1)

top_5_likes = df.loc[df['Type'] == "Photo"].sort_values(by='like',
                                                      ascending=False).head(1)

# %%
# Locate the Photo that has the largest amount of likes in the like column

top_5_likes = df.loc[df['Type'] == "Photo"].sort_values(by='like',
                                                 ascending=False).head(1)

# %%
# Your code here
top_5_likes
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
#
#      Lifetime Engaged Users  ...  Lifetime Post Consumptions  \
# 244                    8072  ...                        6242
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 244                                             108752
#
#      Lifetime Post reach by people who like your Page  \
# 244                                             51456
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 244                                               3316
#
#      comment    like  share  Total Interactions  likes_per_impression  \
# 244      372  5172.0  790.0                6334              0.016206
#
#      likes_per_impression_perc
# 244                   1.620641
#
# [1 rows x 21 columns]

# %%
#2nd option w/ multi loc
df.loc[(df['Type'] == "Photo") & (df['like'] == df['like'].max())]
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
#
#      Lifetime Engaged Users  ...  Lifetime Post Consumptions  \
# 244                    8072  ...                        6242
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 244                                             108752
#
#      Lifetime Post reach by people who like your Page  \
# 244                                             51456
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 244                                               3316
#
#      comment    like  share  Total Interactions  likes_per_impression  \
# 244      372  5172.0  790.0                6334              0.016206
#
#      likes_per_impression_perc
# 244                   1.620641
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Task 9: Find the average
#
# What is the mean number of Total Interactions for **Photos**?

# %%
# call_on_students(1)

# %%
# Your code here
df.loc[df['Type'] == "Photo"]["Total Interactions"].mean()
# Out:
# 218.56872037914692

# %%
##alt option
photos = df.loc[df['Type'] == "Photo"]
photos['Total Interactions'].describe()[1]
# Out:
# 218.56872037914692

# %% [markdown]
# <a id='viz'></a>
# # Part 2: Visualization

# %%
# Need more imports!
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 10: Bar Chart
#
# Create a bar chart showing the number of posts per month.
#
# Order the x-axis by month as they appear on the calendar.
#
# Don't forget to add labels and a title.
#
# Use the `plt.subplot` method if you can, but if you can't, resort to the `plt` syntax.

# %%
# call_on_students(1)

# %%
x = df['Post Month'].value_counts().index
height = df['Post Month'].value_counts().index

# %%
height = df['Post Month'].value_counts()
height
# Out:
# 10    57
# 7     52
# 12    50
# 4     50
# 6     49
# 11    45
# 5     37
# 3     36
# 9     35
# 8     34
# 2     26
# 1     25
# Name: Post Month, dtype: int64

# %%
# Your code here
# First need to access the number of posts per month

fig, ax=plt.subplots()

ax.bar(x=x ,height=height)
plt.title('Posts Per Month');
ax.set_xlabel('Post Month')
ax.set_ylabel('Number of Posts');

# %%
# Your code here
# Now need to visualize

- less posts at the beginning of the year
- most posts around holidays
-
# Out:
#   File "<ipython-input-243-3b35447448fc>", line 4
#     - less posts at the beginning of the year
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Let's discuss: what do you notice?
#
# -

# %% [markdown]
# ## Task 11: Scatter Plot
#
# Create a scatter plot that shows the correlation between total interactions and likes.

# %%
# call_on_students(1)

fig, ax=plt.subplots()

ax.scatter(x=df['Total Interactions'] ,y=df['like'])
plt.title('Total Interactions');
ax.set_xlabel('Post Month')
ax.set_ylabel('Interactions vs. Likes');

# %%
fig, ax = plt.subplots()
ax.scatter(x=df['Lifetime Post Total Reach'],y=df['Total Interactions'],s=5,)
ax.set_title('Interactions vs Reach')
ax.set_xlabel('Lifetime Post Total Reach')
ax.set_ylabel('Total Interactions');

# %%
# Your code here

# %% [markdown]
# Let's discuss: what do you notice?
#
# -

# %% [markdown]
# <a id='datastructures'></a>
# # Part 3: Data Structures

# %% [markdown]
# For this next section, we will explore a nested dictionary that comes from the Spotify API.  You won't need to do these kinds of imports and opens on the code challenge, so I'll go ahead and share the code to get started here.
#
# The `data` variable below contains 6 separate pings, each of which returns a list of the top 20 songs streamed on a given day.

# %%
# First we need some imports
import json
import pickle

# %%
# Let's open the pickled file
with open('data/offset_newreleases.p','rb') as read_file:
    responses = pickle.load(read_file)

# %%
# Out:
# [{'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#    'items': [{'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#        'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#        'id': '7CajNmpbOovFoOoasH2HaY',
#        'name': 'Calvin Harris',
#        'type': 'artist',
#        'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3GPiefSRSOxqTrgKJIB7RL'},
#      'href': 'https://api.spotify.com/v1/albums/3GPiefSRSOxqTrgKJIB7RL',
#      'id': '3GPiefSRSOxqTrgKJIB7RL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e5e19455ff5f76c58048bea8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e5e19455ff5f76c58048bea8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e5e19455ff5f76c58048bea8',
#        'width': 64}],
#      'name': 'Over Now (with The Weeknd)',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3GPiefSRSOxqTrgKJIB7RL'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#        'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#        'id': '41MozSoPIsD1dJM0CLPjZF',
#        'name': 'BLACKPINK',
#        'type': 'artist',
#        'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#        'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#        'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#        'name': 'Selena Gomez',
#        'type': 'artist',
#        'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#      'available_markets': ['AD',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HN',
#       'HR',
#       'HU',
#       'IE',
#       'IS',
#       'IT',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'SE',
#       'SI',
#       'SK',
#       'SV',
#       'TN',
#       'UA',
#       'US',
#       'UY',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2VBb4LRcRSACOfJWRUgVZl'},
#      'href': 'https://api.spotify.com/v1/albums/2VBb4LRcRSACOfJWRUgVZl',
#      'id': '2VBb4LRcRSACOfJWRUgVZl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733709f2400b95a7c6f22a7ee0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023709f2400b95a7c6f22a7ee0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513709f2400b95a7c6f22a7ee0',
#        'width': 64}],
#      'name': 'Ice Cream (with Selena Gomez)',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2VBb4LRcRSACOfJWRUgVZl'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#        'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#        'id': '6jJ0s89eD6GaHleKKya26X',
#        'name': 'Katy Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/47zMF6LrXQ8odi6Xv1unC0'},
#      'href': 'https://api.spotify.com/v1/albums/47zMF6LrXQ8odi6Xv1unC0',
#      'id': '47zMF6LrXQ8odi6Xv1unC0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735ebe6cbd74a47a5e8ea88985',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025ebe6cbd74a47a5e8ea88985',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515ebe6cbd74a47a5e8ea88985',
#        'width': 64}],
#      'name': 'Smile',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:47zMF6LrXQ8odi6Xv1unC0'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nS5roXSAGhTGr34W6n7Et'},
#        'href': 'https://api.spotify.com/v1/artists/6nS5roXSAGhTGr34W6n7Et',
#        'id': '6nS5roXSAGhTGr34W6n7Et',
#        'name': 'Disclosure',
#        'type': 'artist',
#        'uri': 'spotify:artist:6nS5roXSAGhTGr34W6n7Et'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6wp1us3xBnYz5qldxrZXRf'},
#      'href': 'https://api.spotify.com/v1/albums/6wp1us3xBnYz5qldxrZXRf',
#      'id': '6wp1us3xBnYz5qldxrZXRf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273355bf68fa788b6d401195b43',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02355bf68fa788b6d401195b43',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851355bf68fa788b6d401195b43',
#        'width': 64}],
#      'name': 'ENERGY (Deluxe)',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:6wp1us3xBnYz5qldxrZXRf'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#        'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#        'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#        'name': 'Giveon',
#        'type': 'artist',
#        'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7pfQDManhpjhxwqps9cveA'},
#      'href': 'https://api.spotify.com/v1/albums/7pfQDManhpjhxwqps9cveA',
#      'id': '7pfQDManhpjhxwqps9cveA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730043fb835eab4610758979a3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020043fb835eab4610758979a3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510043fb835eab4610758979a3',
#        'width': 64}],
#      'name': 'Spotify Singles',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7pfQDManhpjhxwqps9cveA'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MPCFvOQv5cIGfw3jODMF0'},
#        'href': 'https://api.spotify.com/v1/artists/6MPCFvOQv5cIGfw3jODMF0',
#        'id': '6MPCFvOQv5cIGfw3jODMF0',
#        'name': 'Internet Money',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MPCFvOQv5cIGfw3jODMF0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0WqVpr3waP7ajONlqa8Fwj'},
#      'href': 'https://api.spotify.com/v1/albums/0WqVpr3waP7ajONlqa8Fwj',
#      'id': '0WqVpr3waP7ajONlqa8Fwj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27377ddbd0c31707c7308e748a1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0277ddbd0c31707c7308e748a1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485177ddbd0c31707c7308e748a1',
#        'width': 64}],
#      'name': 'B4 The Storm',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:0WqVpr3waP7ajONlqa8Fwj'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0xOeVMOz2fVg5BJY3N6akT'},
#        'href': 'https://api.spotify.com/v1/artists/0xOeVMOz2fVg5BJY3N6akT',
#        'id': '0xOeVMOz2fVg5BJY3N6akT',
#        'name': 'Jaden',
#        'type': 'artist',
#        'uri': 'spotify:artist:0xOeVMOz2fVg5BJY3N6akT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2NuZ1TloomufyKf57ZLBQn'},
#      'href': 'https://api.spotify.com/v1/albums/2NuZ1TloomufyKf57ZLBQn',
#      'id': '2NuZ1TloomufyKf57ZLBQn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273421325b3842bc2f4cf65f1d3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02421325b3842bc2f4cf65f1d3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851421325b3842bc2f4cf65f1d3',
#        'width': 64}],
#      'name': 'CTV3: Cool Tape Vol. 3',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:2NuZ1TloomufyKf57ZLBQn'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YLtscXsxbVgi031ovDDdh'},
#        'href': 'https://api.spotify.com/v1/artists/4YLtscXsxbVgi031ovDDdh',
#        'id': '4YLtscXsxbVgi031ovDDdh',
#        'name': 'Chris Stapleton',
#        'type': 'artist',
#        'uri': 'spotify:artist:4YLtscXsxbVgi031ovDDdh'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4AOloVYcXn1aa4p4IhwhRM'},
#      'href': 'https://api.spotify.com/v1/albums/4AOloVYcXn1aa4p4IhwhRM',
#      'id': '4AOloVYcXn1aa4p4IhwhRM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d7d74af20c3a7ac6a0b7a60b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d7d74af20c3a7ac6a0b7a60b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d7d74af20c3a7ac6a0b7a60b',
#        'width': 64}],
#      'name': 'Starting Over',
#      'release_date': '2020-08-27',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4AOloVYcXn1aa4p4IhwhRM'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dHt1vcEm9qb8fCyLcB3HL'},
#        'href': 'https://api.spotify.com/v1/artists/5dHt1vcEm9qb8fCyLcB3HL',
#        'id': '5dHt1vcEm9qb8fCyLcB3HL',
#        'name': 'A$AP Ferg',
#        'type': 'artist',
#        'uri': 'spotify:artist:5dHt1vcEm9qb8fCyLcB3HL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7bwhQ4ir83KULY8HnhhpJm'},
#      'href': 'https://api.spotify.com/v1/albums/7bwhQ4ir83KULY8HnhhpJm',
#      'id': '7bwhQ4ir83KULY8HnhhpJm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734db665e177c24986d3c9992c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024db665e177c24986d3c9992c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514db665e177c24986d3c9992c',
#        'width': 64}],
#      'name': 'No Ceilings (feat. Lil Wayne & Jay Gwuapo)',
#      'release_date': '2020-08-27',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7bwhQ4ir83KULY8HnhhpJm'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0u6GtibW46tFX7koQ6uNJZ'},
#        'href': 'https://api.spotify.com/v1/artists/0u6GtibW46tFX7koQ6uNJZ',
#        'id': '0u6GtibW46tFX7koQ6uNJZ',
#        'name': 'Topic',
#        'type': 'artist',
#        'uri': 'spotify:artist:0u6GtibW46tFX7koQ6uNJZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#        'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#        'id': '5Wg2b4Mp42gicxEeDNawf7',
#        'name': 'A7S',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2u2Cs0hyDvoYayBYEvpRnf'},
#      'href': 'https://api.spotify.com/v1/albums/2u2Cs0hyDvoYayBYEvpRnf',
#      'id': '2u2Cs0hyDvoYayBYEvpRnf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731ce707b9fe8280a85361c97e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021ce707b9fe8280a85361c97e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511ce707b9fe8280a85361c97e',
#        'width': 64}],
#      'name': 'Why Do You Lie To Me',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2u2Cs0hyDvoYayBYEvpRnf'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0c173mlxpT3dSFRgMO8XPh'},
#        'href': 'https://api.spotify.com/v1/artists/0c173mlxpT3dSFRgMO8XPh',
#        'id': '0c173mlxpT3dSFRgMO8XPh',
#        'name': 'Big Sean',
#        'type': 'artist',
#        'uri': 'spotify:artist:0c173mlxpT3dSFRgMO8XPh'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EeQBlQJFiAfJeVN2vT9s0'},
#        'href': 'https://api.spotify.com/v1/artists/0EeQBlQJFiAfJeVN2vT9s0',
#        'id': '0EeQBlQJFiAfJeVN2vT9s0',
#        'name': 'Nipsey Hussle',
#        'type': 'artist',
#        'uri': 'spotify:artist:0EeQBlQJFiAfJeVN2vT9s0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4RCSDGVMSrMZXgHre4W3oa'},
#      'href': 'https://api.spotify.com/v1/albums/4RCSDGVMSrMZXgHre4W3oa',
#      'id': '4RCSDGVMSrMZXgHre4W3oa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ae115d187f0b5dd7ba6751b0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ae115d187f0b5dd7ba6751b0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ae115d187f0b5dd7ba6751b0',
#        'width': 64}],
#      'name': 'Deep Reverence',
#      'release_date': '2020-08-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4RCSDGVMSrMZXgHre4W3oa'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6w3SkAHYPsQ1bxV7VDlG5y'},
#        'href': 'https://api.spotify.com/v1/artists/6w3SkAHYPsQ1bxV7VDlG5y',
#        'id': '6w3SkAHYPsQ1bxV7VDlG5y',
#        'name': 'Cazzu',
#        'type': 'artist',
#        'uri': 'spotify:artist:6w3SkAHYPsQ1bxV7VDlG5y'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3cOK1UKpkM2v2xtcbNFzzc'},
#      'href': 'https://api.spotify.com/v1/albums/3cOK1UKpkM2v2xtcbNFzzc',
#      'id': '3cOK1UKpkM2v2xtcbNFzzc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273205ac7dee5566c878553d4ea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02205ac7dee5566c878553d4ea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851205ac7dee5566c878553d4ea',
#        'width': 64}],
#      'name': 'Una Niña Inútil',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:3cOK1UKpkM2v2xtcbNFzzc'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hNaHKp2Za5YdOAG0WnRbc'},
#        'href': 'https://api.spotify.com/v1/artists/1hNaHKp2Za5YdOAG0WnRbc',
#        'id': '1hNaHKp2Za5YdOAG0WnRbc',
#        'name': 'Tiwa Savage',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hNaHKp2Za5YdOAG0WnRbc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0v0pKqegGprcnGYUGitYvO'},
#      'href': 'https://api.spotify.com/v1/albums/0v0pKqegGprcnGYUGitYvO',
#      'id': '0v0pKqegGprcnGYUGitYvO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27325bececcdc7bcade57bec01b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0225bececcdc7bcade57bec01b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485125bececcdc7bcade57bec01b',
#        'width': 64}],
#      'name': 'Celia',
#      'release_date': '2020-08-27',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0v0pKqegGprcnGYUGitYvO'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4KJ6jujcNPzOyhdNoiNftp'},
#        'href': 'https://api.spotify.com/v1/artists/4KJ6jujcNPzOyhdNoiNftp',
#        'id': '4KJ6jujcNPzOyhdNoiNftp',
#        'name': 'lovelytheband',
#        'type': 'artist',
#        'uri': 'spotify:artist:4KJ6jujcNPzOyhdNoiNftp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/190bl0MFluUBIYvvheHTw3'},
#      'href': 'https://api.spotify.com/v1/albums/190bl0MFluUBIYvvheHTw3',
#      'id': '190bl0MFluUBIYvvheHTw3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27321c67d105698f0af4f956f0f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0221c67d105698f0af4f956f0f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485121c67d105698f0af4f956f0f',
#        'width': 64}],
#      'name': 'conversations with myself about you',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:190bl0MFluUBIYvvheHTw3'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mKqFxGMS5TGDZI3XkT5Rt'},
#        'href': 'https://api.spotify.com/v1/artists/6mKqFxGMS5TGDZI3XkT5Rt',
#        'id': '6mKqFxGMS5TGDZI3XkT5Rt',
#        'name': 'Angel Olsen',
#        'type': 'artist',
#        'uri': 'spotify:artist:6mKqFxGMS5TGDZI3XkT5Rt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6j4BnZet4BZ8YgSUZ3n1cf'},
#      'href': 'https://api.spotify.com/v1/albums/6j4BnZet4BZ8YgSUZ3n1cf',
#      'id': '6j4BnZet4BZ8YgSUZ3n1cf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf7ece51a28e1fe747703443',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf7ece51a28e1fe747703443',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf7ece51a28e1fe747703443',
#        'width': 64}],
#      'name': 'Whole New Mess',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6j4BnZet4BZ8YgSUZ3n1cf'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ITI6SEoUZMIXXkzCfr4oE'},
#        'href': 'https://api.spotify.com/v1/artists/5ITI6SEoUZMIXXkzCfr4oE',
#        'id': '5ITI6SEoUZMIXXkzCfr4oE',
#        'name': 'Aluna',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ITI6SEoUZMIXXkzCfr4oE'}],
#      'available_markets': ['AE',
#       'AR',
#       'AU',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'DO',
#       'EC',
#       'GT',
#       'HK',
#       'HN',
#       'ID',
#       'IL',
#       'IN',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'MX',
#       'MY',
#       'NI',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PS',
#       'PY',
#       'QA',
#       'SA',
#       'SG',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0cFJfTwmx4KOM9zEy9i2nB'},
#      'href': 'https://api.spotify.com/v1/albums/0cFJfTwmx4KOM9zEy9i2nB',
#      'id': '0cFJfTwmx4KOM9zEy9i2nB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735c644b84ee541cd05a67e50f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025c644b84ee541cd05a67e50f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515c644b84ee541cd05a67e50f',
#        'width': 64}],
#      'name': 'Renaissance',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0cFJfTwmx4KOM9zEy9i2nB'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ryoUS0W8qXokfMxrlJt6O'},
#        'href': 'https://api.spotify.com/v1/artists/4ryoUS0W8qXokfMxrlJt6O',
#        'id': '4ryoUS0W8qXokfMxrlJt6O',
#        'name': 'Skip Marley',
#        'type': 'artist',
#        'uri': 'spotify:artist:4ryoUS0W8qXokfMxrlJt6O'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3LrRzezQmsqxC2eyqVvdAr'},
#      'href': 'https://api.spotify.com/v1/albums/3LrRzezQmsqxC2eyqVvdAr',
#      'id': '3LrRzezQmsqxC2eyqVvdAr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731e310ac72c0b4221ac8cc6b5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021e310ac72c0b4221ac8cc6b5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511e310ac72c0b4221ac8cc6b5',
#        'width': 64}],
#      'name': 'Higher Place',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:3LrRzezQmsqxC2eyqVvdAr'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uwAm6vQy7kWPS2bciKWx9'},
#        'href': 'https://api.spotify.com/v1/artists/3uwAm6vQy7kWPS2bciKWx9',
#        'id': '3uwAm6vQy7kWPS2bciKWx9',
#        'name': 'girl in red',
#        'type': 'artist',
#        'uri': 'spotify:artist:3uwAm6vQy7kWPS2bciKWx9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0wwsKyplQfWHtLxlMvVkvP'},
#      'href': 'https://api.spotify.com/v1/albums/0wwsKyplQfWHtLxlMvVkvP',
#      'id': '0wwsKyplQfWHtLxlMvVkvP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c89027bc69c39397226421e3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c89027bc69c39397226421e3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c89027bc69c39397226421e3',
#        'width': 64}],
#      'name': 'rue',
#      'release_date': '2020-08-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0wwsKyplQfWHtLxlMvVkvP'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0u2FHSq3ln94y5Q57xazwf'},
#        'href': 'https://api.spotify.com/v1/artists/0u2FHSq3ln94y5Q57xazwf',
#        'id': '0u2FHSq3ln94y5Q57xazwf',
#        'name': 'Keith Urban',
#        'type': 'artist',
#        'uri': 'spotify:artist:0u2FHSq3ln94y5Q57xazwf'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Q81TJjvwrir41wBsFUSNm'},
#      'href': 'https://api.spotify.com/v1/albums/1Q81TJjvwrir41wBsFUSNm',
#      'id': '1Q81TJjvwrir41wBsFUSNm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730d2b606f68b28befc35a1114',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020d2b606f68b28befc35a1114',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510d2b606f68b28befc35a1114',
#        'width': 64}],
#      'name': 'Tumbleweed',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1Q81TJjvwrir41wBsFUSNm'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IDLDx25HU1nQMKde4n61a'},
#        'href': 'https://api.spotify.com/v1/artists/2IDLDx25HU1nQMKde4n61a',
#        'id': '2IDLDx25HU1nQMKde4n61a',
#        'name': 'Rich Brian',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IDLDx25HU1nQMKde4n61a'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fekFzT8lQv8sZjPGn7JqW'},
#      'href': 'https://api.spotify.com/v1/albums/7fekFzT8lQv8sZjPGn7JqW',
#      'id': '7fekFzT8lQv8sZjPGn7JqW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733c9153fe1cc34dcf27d477aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023c9153fe1cc34dcf27d477aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513c9153fe1cc34dcf27d477aa',
#        'width': 64}],
#      'name': '1999',
#      'release_date': '2020-08-25',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:7fekFzT8lQv8sZjPGn7JqW'}],
#    'limit': 20,
#    'next': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#    'offset': 0,
#    'previous': None,
#    'total': 100}},
#  {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#    'items': [{'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xYXYzm9H3RzyQgBrYwIcx'},
#        'href': 'https://api.spotify.com/v1/artists/3xYXYzm9H3RzyQgBrYwIcx',
#        'id': '3xYXYzm9H3RzyQgBrYwIcx',
#        'name': 'Colter Wall',
#        'type': 'artist',
#        'uri': 'spotify:artist:3xYXYzm9H3RzyQgBrYwIcx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1RbJr45fQ7wvjfT2poSHwI'},
#      'href': 'https://api.spotify.com/v1/albums/1RbJr45fQ7wvjfT2poSHwI',
#      'id': '1RbJr45fQ7wvjfT2poSHwI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273953b105656e8b3551855e82e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02953b105656e8b3551855e82e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851953b105656e8b3551855e82e',
#        'width': 64}],
#      'name': 'Western Swing & Waltzes and Other Punchy Songs',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1RbJr45fQ7wvjfT2poSHwI'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3X458ddYA2YcVWuVIGGOYe'},
#        'href': 'https://api.spotify.com/v1/artists/3X458ddYA2YcVWuVIGGOYe',
#        'id': '3X458ddYA2YcVWuVIGGOYe',
#        'name': 'Toni Braxton',
#        'type': 'artist',
#        'uri': 'spotify:artist:3X458ddYA2YcVWuVIGGOYe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
# ...
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485152c75ed37313b889447011ef',
#        'width': 64}],
#      'name': 'Laugh Now Cry Later (feat. Lil Durk)',
#      'release_date': '2020-08-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0qGdc7fNq9RNIPEzZufa43'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#        'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#        'id': '5YGY8feqx7naU7z4HrwZM6',
#        'name': 'Miley Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7z5fmW3FDD6jlpJtwMXV51'},
#      'href': 'https://api.spotify.com/v1/albums/7z5fmW3FDD6jlpJtwMXV51',
#      'id': '7z5fmW3FDD6jlpJtwMXV51',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d59c3c489691c8b41043cab2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d59c3c489691c8b41043cab2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d59c3c489691c8b41043cab2',
#        'width': 64}],
#      'name': 'Midnight Sky',
#      'release_date': '2020-08-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7z5fmW3FDD6jlpJtwMXV51'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cZQSpDsxgKIX2yW5OR9Ot'},
#        'href': 'https://api.spotify.com/v1/artists/1cZQSpDsxgKIX2yW5OR9Ot',
#        'id': '1cZQSpDsxgKIX2yW5OR9Ot',
#        'name': 'Lennon Stella',
#        'type': 'artist',
#        'uri': 'spotify:artist:1cZQSpDsxgKIX2yW5OR9Ot'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0dlIoNzi1FAca3VcyPFj5S'},
#      'href': 'https://api.spotify.com/v1/albums/0dlIoNzi1FAca3VcyPFj5S',
#      'id': '0dlIoNzi1FAca3VcyPFj5S',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f77ea7871f72c8458c5cb61e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f77ea7871f72c8458c5cb61e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f77ea7871f72c8458c5cb61e',
#        'width': 64}],
#      'name': 'Spotify Singles',
#      'release_date': '2020-08-19',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:0dlIoNzi1FAca3VcyPFj5S'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VuMaDnrHyPL1p4EHjYLi7'},
#        'href': 'https://api.spotify.com/v1/artists/6VuMaDnrHyPL1p4EHjYLi7',
#        'id': '6VuMaDnrHyPL1p4EHjYLi7',
#        'name': 'Charlie Puth',
#        'type': 'artist',
#        'uri': 'spotify:artist:6VuMaDnrHyPL1p4EHjYLi7'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#        'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#        'id': '2cFrymmkijnjDg9SS92EPM',
#        'name': 'blackbear',
#        'type': 'artist',
#        'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7DLhC8ZXggJDd9HSa1PVGO'},
#      'href': 'https://api.spotify.com/v1/albums/7DLhC8ZXggJDd9HSa1PVGO',
#      'id': '7DLhC8ZXggJDd9HSa1PVGO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e0e9139ff2f8256ebab8fc5b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e0e9139ff2f8256ebab8fc5b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e0e9139ff2f8256ebab8fc5b',
#        'width': 64}],
#      'name': 'Hard On Yourself',
#      'release_date': '2020-08-14',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7DLhC8ZXggJDd9HSa1PVGO'},
#     {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3wcj11K77LjEY1PkEazffa'},
#        'href': 'https://api.spotify.com/v1/artists/3wcj11K77LjEY1PkEazffa',
#        'id': '3wcj11K77LjEY1PkEazffa',
#        'name': 'Burna Boy',
#        'type': 'artist',
#        'uri': 'spotify:artist:3wcj11K77LjEY1PkEazffa'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/218CJKDCszsQQj7Amk7vIu'},
#      'href': 'https://api.spotify.com/v1/albums/218CJKDCszsQQj7Amk7vIu',
#      'id': '218CJKDCszsQQj7Amk7vIu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f6a834ad44c8f4a43051d43c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f6a834ad44c8f4a43051d43c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f6a834ad44c8f4a43051d43c',
#        'width': 64}],
#      'name': 'Twice As Tall',
#      'release_date': '2020-08-13',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:218CJKDCszsQQj7Amk7vIu'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3DiDSECUqqY1AuBP8qtaIa'},
#        'href': 'https://api.spotify.com/v1/artists/3DiDSECUqqY1AuBP8qtaIa',
#        'id': '3DiDSECUqqY1AuBP8qtaIa',
#        'name': 'Alicia Keys',
#        'type': 'artist',
#        'uri': 'spotify:artist:3DiDSECUqqY1AuBP8qtaIa'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/062XA53aUGExhE7e8ngYQO'},
#      'href': 'https://api.spotify.com/v1/albums/062XA53aUGExhE7e8ngYQO',
#      'id': '062XA53aUGExhE7e8ngYQO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba60f6810163afc8d6af7311',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ba60f6810163afc8d6af7311',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ba60f6810163afc8d6af7311',
#        'width': 64}],
#      'name': 'So Done (feat. Khalid)',
#      'release_date': '2020-08-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:062XA53aUGExhE7e8ngYQO'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#        'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#        'id': '0C0XlULifJtAgn6ZNCW2eu',
#        'name': 'The Killers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3UL8kVLqJVXaS3tYsYpqf2'},
#      'href': 'https://api.spotify.com/v1/albums/3UL8kVLqJVXaS3tYsYpqf2',
#      'id': '3UL8kVLqJVXaS3tYsYpqf2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738ba71359b7d55ac913be805d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028ba71359b7d55ac913be805d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518ba71359b7d55ac913be805d',
#        'width': 64}],
#      'name': 'Dying Breed',
#      'release_date': '2020-08-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3UL8kVLqJVXaS3tYsYpqf2'},
#     {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3oSJ7TBVCWMDMiYjXNiCKE'},
#        'href': 'https://api.spotify.com/v1/artists/3oSJ7TBVCWMDMiYjXNiCKE',
#        'id': '3oSJ7TBVCWMDMiYjXNiCKE',
#        'name': 'Kane Brown',
#        'type': 'artist',
#        'uri': 'spotify:artist:3oSJ7TBVCWMDMiYjXNiCKE'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/014fzAwHbsvUolo3ap8P38'},
#      'href': 'https://api.spotify.com/v1/albums/014fzAwHbsvUolo3ap8P38',
#      'id': '014fzAwHbsvUolo3ap8P38',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273da0fbf5a54052f21c8499556',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02da0fbf5a54052f21c8499556',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851da0fbf5a54052f21c8499556',
#        'width': 64}],
#      'name': 'Mixtape Vol. 1 - EP',
#      'release_date': '2020-08-14',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:014fzAwHbsvUolo3ap8P38'}],
#    'limit': 20,
#    'next': None,
#    'offset': 80,
#    'previous': 'https://api.spotify.com/v1/browse/new-releases?offset=60&limit=20',
#    'total': 100}},
#  {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=100&limit=20',
#    'items': [],
#    'limit': 20,
#    'next': None,
#    'offset': 100,
#    'previous': 'https://api.spotify.com/v1/browse/new-releases?offset=80&limit=20',
#    'total': 100}}]

# %%
data = [json.loads(r) for r in responses]

# %%
# Sanity check - we said there would be 6 pings, are there?
len(data)
# Out:
# 6

# %% [markdown]
# We will work only with the first response.

# %%
first_response = data[0]

# %%
first_response
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#   'items': [{'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#       'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#       'id': '7CajNmpbOovFoOoasH2HaY',
#       'name': 'Calvin Harris',
#       'type': 'artist',
#       'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3GPiefSRSOxqTrgKJIB7RL'},
#     'href': 'https://api.spotify.com/v1/albums/3GPiefSRSOxqTrgKJIB7RL',
#     'id': '3GPiefSRSOxqTrgKJIB7RL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e5e19455ff5f76c58048bea8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e5e19455ff5f76c58048bea8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e5e19455ff5f76c58048bea8',
#       'width': 64}],
#     'name': 'Over Now (with The Weeknd)',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3GPiefSRSOxqTrgKJIB7RL'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#       'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#       'id': '41MozSoPIsD1dJM0CLPjZF',
#       'name': 'BLACKPINK',
#       'type': 'artist',
#       'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#       'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#       'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#       'name': 'Selena Gomez',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HN',
#      'HR',
#      'HU',
#      'IE',
#      'IS',
#      'IT',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SI',
#      'SK',
#      'SV',
#      'TN',
#      'UA',
#      'US',
#      'UY',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2VBb4LRcRSACOfJWRUgVZl'},
#     'href': 'https://api.spotify.com/v1/albums/2VBb4LRcRSACOfJWRUgVZl',
#     'id': '2VBb4LRcRSACOfJWRUgVZl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733709f2400b95a7c6f22a7ee0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023709f2400b95a7c6f22a7ee0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513709f2400b95a7c6f22a7ee0',
#       'width': 64}],
#     'name': 'Ice Cream (with Selena Gomez)',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2VBb4LRcRSACOfJWRUgVZl'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/47zMF6LrXQ8odi6Xv1unC0'},
#     'href': 'https://api.spotify.com/v1/albums/47zMF6LrXQ8odi6Xv1unC0',
#     'id': '47zMF6LrXQ8odi6Xv1unC0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735ebe6cbd74a47a5e8ea88985',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025ebe6cbd74a47a5e8ea88985',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515ebe6cbd74a47a5e8ea88985',
#       'width': 64}],
#     'name': 'Smile',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:47zMF6LrXQ8odi6Xv1unC0'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nS5roXSAGhTGr34W6n7Et'},
#       'href': 'https://api.spotify.com/v1/artists/6nS5roXSAGhTGr34W6n7Et',
#       'id': '6nS5roXSAGhTGr34W6n7Et',
#       'name': 'Disclosure',
#       'type': 'artist',
#       'uri': 'spotify:artist:6nS5roXSAGhTGr34W6n7Et'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6wp1us3xBnYz5qldxrZXRf'},
#     'href': 'https://api.spotify.com/v1/albums/6wp1us3xBnYz5qldxrZXRf',
#     'id': '6wp1us3xBnYz5qldxrZXRf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273355bf68fa788b6d401195b43',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02355bf68fa788b6d401195b43',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851355bf68fa788b6d401195b43',
#       'width': 64}],
#     'name': 'ENERGY (Deluxe)',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:6wp1us3xBnYz5qldxrZXRf'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#       'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#       'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#       'name': 'Giveon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7pfQDManhpjhxwqps9cveA'},
#     'href': 'https://api.spotify.com/v1/albums/7pfQDManhpjhxwqps9cveA',
#     'id': '7pfQDManhpjhxwqps9cveA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730043fb835eab4610758979a3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020043fb835eab4610758979a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510043fb835eab4610758979a3',
#       'width': 64}],
#     'name': 'Spotify Singles',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:7pfQDManhpjhxwqps9cveA'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MPCFvOQv5cIGfw3jODMF0'},
#       'href': 'https://api.spotify.com/v1/artists/6MPCFvOQv5cIGfw3jODMF0',
#       'id': '6MPCFvOQv5cIGfw3jODMF0',
#       'name': 'Internet Money',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MPCFvOQv5cIGfw3jODMF0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0WqVpr3waP7ajONlqa8Fwj'},
#     'href': 'https://api.spotify.com/v1/albums/0WqVpr3waP7ajONlqa8Fwj',
#     'id': '0WqVpr3waP7ajONlqa8Fwj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27377ddbd0c31707c7308e748a1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0277ddbd0c31707c7308e748a1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485177ddbd0c31707c7308e748a1',
#       'width': 64}],
#     'name': 'B4 The Storm',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:0WqVpr3waP7ajONlqa8Fwj'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0xOeVMOz2fVg5BJY3N6akT'},
#       'href': 'https://api.spotify.com/v1/artists/0xOeVMOz2fVg5BJY3N6akT',
#       'id': '0xOeVMOz2fVg5BJY3N6akT',
#       'name': 'Jaden',
#       'type': 'artist',
#       'uri': 'spotify:artist:0xOeVMOz2fVg5BJY3N6akT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2NuZ1TloomufyKf57ZLBQn'},
#     'href': 'https://api.spotify.com/v1/albums/2NuZ1TloomufyKf57ZLBQn',
#     'id': '2NuZ1TloomufyKf57ZLBQn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273421325b3842bc2f4cf65f1d3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02421325b3842bc2f4cf65f1d3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851421325b3842bc2f4cf65f1d3',
#       'width': 64}],
#     'name': 'CTV3: Cool Tape Vol. 3',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:2NuZ1TloomufyKf57ZLBQn'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YLtscXsxbVgi031ovDDdh'},
#       'href': 'https://api.spotify.com/v1/artists/4YLtscXsxbVgi031ovDDdh',
#       'id': '4YLtscXsxbVgi031ovDDdh',
#       'name': 'Chris Stapleton',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YLtscXsxbVgi031ovDDdh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4AOloVYcXn1aa4p4IhwhRM'},
#     'href': 'https://api.spotify.com/v1/albums/4AOloVYcXn1aa4p4IhwhRM',
#     'id': '4AOloVYcXn1aa4p4IhwhRM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d7d74af20c3a7ac6a0b7a60b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d7d74af20c3a7ac6a0b7a60b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d7d74af20c3a7ac6a0b7a60b',
#       'width': 64}],
#     'name': 'Starting Over',
#     'release_date': '2020-08-27',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4AOloVYcXn1aa4p4IhwhRM'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dHt1vcEm9qb8fCyLcB3HL'},
#       'href': 'https://api.spotify.com/v1/artists/5dHt1vcEm9qb8fCyLcB3HL',
#       'id': '5dHt1vcEm9qb8fCyLcB3HL',
#       'name': 'A$AP Ferg',
#       'type': 'artist',
#       'uri': 'spotify:artist:5dHt1vcEm9qb8fCyLcB3HL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7bwhQ4ir83KULY8HnhhpJm'},
#     'href': 'https://api.spotify.com/v1/albums/7bwhQ4ir83KULY8HnhhpJm',
#     'id': '7bwhQ4ir83KULY8HnhhpJm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734db665e177c24986d3c9992c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024db665e177c24986d3c9992c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514db665e177c24986d3c9992c',
#       'width': 64}],
#     'name': 'No Ceilings (feat. Lil Wayne & Jay Gwuapo)',
#     'release_date': '2020-08-27',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7bwhQ4ir83KULY8HnhhpJm'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0u6GtibW46tFX7koQ6uNJZ'},
#       'href': 'https://api.spotify.com/v1/artists/0u6GtibW46tFX7koQ6uNJZ',
#       'id': '0u6GtibW46tFX7koQ6uNJZ',
#       'name': 'Topic',
#       'type': 'artist',
#       'uri': 'spotify:artist:0u6GtibW46tFX7koQ6uNJZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#       'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#       'id': '5Wg2b4Mp42gicxEeDNawf7',
#       'name': 'A7S',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2u2Cs0hyDvoYayBYEvpRnf'},
#     'href': 'https://api.spotify.com/v1/albums/2u2Cs0hyDvoYayBYEvpRnf',
#     'id': '2u2Cs0hyDvoYayBYEvpRnf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731ce707b9fe8280a85361c97e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021ce707b9fe8280a85361c97e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511ce707b9fe8280a85361c97e',
#       'width': 64}],
#     'name': 'Why Do You Lie To Me',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2u2Cs0hyDvoYayBYEvpRnf'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0c173mlxpT3dSFRgMO8XPh'},
#       'href': 'https://api.spotify.com/v1/artists/0c173mlxpT3dSFRgMO8XPh',
#       'id': '0c173mlxpT3dSFRgMO8XPh',
#       'name': 'Big Sean',
#       'type': 'artist',
#       'uri': 'spotify:artist:0c173mlxpT3dSFRgMO8XPh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EeQBlQJFiAfJeVN2vT9s0'},
#       'href': 'https://api.spotify.com/v1/artists/0EeQBlQJFiAfJeVN2vT9s0',
#       'id': '0EeQBlQJFiAfJeVN2vT9s0',
#       'name': 'Nipsey Hussle',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EeQBlQJFiAfJeVN2vT9s0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4RCSDGVMSrMZXgHre4W3oa'},
#     'href': 'https://api.spotify.com/v1/albums/4RCSDGVMSrMZXgHre4W3oa',
#     'id': '4RCSDGVMSrMZXgHre4W3oa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ae115d187f0b5dd7ba6751b0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ae115d187f0b5dd7ba6751b0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ae115d187f0b5dd7ba6751b0',
#       'width': 64}],
#     'name': 'Deep Reverence',
#     'release_date': '2020-08-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4RCSDGVMSrMZXgHre4W3oa'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6w3SkAHYPsQ1bxV7VDlG5y'},
#       'href': 'https://api.spotify.com/v1/artists/6w3SkAHYPsQ1bxV7VDlG5y',
#       'id': '6w3SkAHYPsQ1bxV7VDlG5y',
#       'name': 'Cazzu',
#       'type': 'artist',
#       'uri': 'spotify:artist:6w3SkAHYPsQ1bxV7VDlG5y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3cOK1UKpkM2v2xtcbNFzzc'},
#     'href': 'https://api.spotify.com/v1/albums/3cOK1UKpkM2v2xtcbNFzzc',
#     'id': '3cOK1UKpkM2v2xtcbNFzzc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273205ac7dee5566c878553d4ea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02205ac7dee5566c878553d4ea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851205ac7dee5566c878553d4ea',
#       'width': 64}],
#     'name': 'Una Niña Inútil',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:3cOK1UKpkM2v2xtcbNFzzc'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hNaHKp2Za5YdOAG0WnRbc'},
#       'href': 'https://api.spotify.com/v1/artists/1hNaHKp2Za5YdOAG0WnRbc',
#       'id': '1hNaHKp2Za5YdOAG0WnRbc',
#       'name': 'Tiwa Savage',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hNaHKp2Za5YdOAG0WnRbc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0v0pKqegGprcnGYUGitYvO'},
#     'href': 'https://api.spotify.com/v1/albums/0v0pKqegGprcnGYUGitYvO',
#     'id': '0v0pKqegGprcnGYUGitYvO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27325bececcdc7bcade57bec01b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0225bececcdc7bcade57bec01b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485125bececcdc7bcade57bec01b',
#       'width': 64}],
#     'name': 'Celia',
#     'release_date': '2020-08-27',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:0v0pKqegGprcnGYUGitYvO'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4KJ6jujcNPzOyhdNoiNftp'},
#       'href': 'https://api.spotify.com/v1/artists/4KJ6jujcNPzOyhdNoiNftp',
#       'id': '4KJ6jujcNPzOyhdNoiNftp',
#       'name': 'lovelytheband',
#       'type': 'artist',
#       'uri': 'spotify:artist:4KJ6jujcNPzOyhdNoiNftp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/190bl0MFluUBIYvvheHTw3'},
#     'href': 'https://api.spotify.com/v1/albums/190bl0MFluUBIYvvheHTw3',
#     'id': '190bl0MFluUBIYvvheHTw3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27321c67d105698f0af4f956f0f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0221c67d105698f0af4f956f0f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485121c67d105698f0af4f956f0f',
#       'width': 64}],
#     'name': 'conversations with myself about you',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:190bl0MFluUBIYvvheHTw3'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mKqFxGMS5TGDZI3XkT5Rt'},
#       'href': 'https://api.spotify.com/v1/artists/6mKqFxGMS5TGDZI3XkT5Rt',
#       'id': '6mKqFxGMS5TGDZI3XkT5Rt',
#       'name': 'Angel Olsen',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mKqFxGMS5TGDZI3XkT5Rt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6j4BnZet4BZ8YgSUZ3n1cf'},
#     'href': 'https://api.spotify.com/v1/albums/6j4BnZet4BZ8YgSUZ3n1cf',
#     'id': '6j4BnZet4BZ8YgSUZ3n1cf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bf7ece51a28e1fe747703443',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bf7ece51a28e1fe747703443',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bf7ece51a28e1fe747703443',
#       'width': 64}],
#     'name': 'Whole New Mess',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6j4BnZet4BZ8YgSUZ3n1cf'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ITI6SEoUZMIXXkzCfr4oE'},
#       'href': 'https://api.spotify.com/v1/artists/5ITI6SEoUZMIXXkzCfr4oE',
#       'id': '5ITI6SEoUZMIXXkzCfr4oE',
#       'name': 'Aluna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ITI6SEoUZMIXXkzCfr4oE'}],
#     'available_markets': ['AE',
#      'AR',
#      'AU',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'DO',
#      'EC',
#      'GT',
#      'HK',
#      'HN',
#      'ID',
#      'IL',
#      'IN',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'MX',
#      'MY',
#      'NI',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PS',
#      'PY',
#      'QA',
#      'SA',
#      'SG',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0cFJfTwmx4KOM9zEy9i2nB'},
#     'href': 'https://api.spotify.com/v1/albums/0cFJfTwmx4KOM9zEy9i2nB',
#     'id': '0cFJfTwmx4KOM9zEy9i2nB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735c644b84ee541cd05a67e50f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025c644b84ee541cd05a67e50f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515c644b84ee541cd05a67e50f',
#       'width': 64}],
#     'name': 'Renaissance',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:0cFJfTwmx4KOM9zEy9i2nB'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ryoUS0W8qXokfMxrlJt6O'},
#       'href': 'https://api.spotify.com/v1/artists/4ryoUS0W8qXokfMxrlJt6O',
#       'id': '4ryoUS0W8qXokfMxrlJt6O',
#       'name': 'Skip Marley',
#       'type': 'artist',
#       'uri': 'spotify:artist:4ryoUS0W8qXokfMxrlJt6O'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3LrRzezQmsqxC2eyqVvdAr'},
#     'href': 'https://api.spotify.com/v1/albums/3LrRzezQmsqxC2eyqVvdAr',
#     'id': '3LrRzezQmsqxC2eyqVvdAr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731e310ac72c0b4221ac8cc6b5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021e310ac72c0b4221ac8cc6b5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511e310ac72c0b4221ac8cc6b5',
#       'width': 64}],
#     'name': 'Higher Place',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:3LrRzezQmsqxC2eyqVvdAr'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uwAm6vQy7kWPS2bciKWx9'},
#       'href': 'https://api.spotify.com/v1/artists/3uwAm6vQy7kWPS2bciKWx9',
#       'id': '3uwAm6vQy7kWPS2bciKWx9',
#       'name': 'girl in red',
#       'type': 'artist',
#       'uri': 'spotify:artist:3uwAm6vQy7kWPS2bciKWx9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0wwsKyplQfWHtLxlMvVkvP'},
#     'href': 'https://api.spotify.com/v1/albums/0wwsKyplQfWHtLxlMvVkvP',
#     'id': '0wwsKyplQfWHtLxlMvVkvP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c89027bc69c39397226421e3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c89027bc69c39397226421e3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c89027bc69c39397226421e3',
#       'width': 64}],
#     'name': 'rue',
#     'release_date': '2020-08-26',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0wwsKyplQfWHtLxlMvVkvP'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0u2FHSq3ln94y5Q57xazwf'},
#       'href': 'https://api.spotify.com/v1/artists/0u2FHSq3ln94y5Q57xazwf',
#       'id': '0u2FHSq3ln94y5Q57xazwf',
#       'name': 'Keith Urban',
#       'type': 'artist',
#       'uri': 'spotify:artist:0u2FHSq3ln94y5Q57xazwf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Q81TJjvwrir41wBsFUSNm'},
#     'href': 'https://api.spotify.com/v1/albums/1Q81TJjvwrir41wBsFUSNm',
#     'id': '1Q81TJjvwrir41wBsFUSNm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730d2b606f68b28befc35a1114',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020d2b606f68b28befc35a1114',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510d2b606f68b28befc35a1114',
#       'width': 64}],
#     'name': 'Tumbleweed',
#     'release_date': '2020-08-28',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1Q81TJjvwrir41wBsFUSNm'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IDLDx25HU1nQMKde4n61a'},
#       'href': 'https://api.spotify.com/v1/artists/2IDLDx25HU1nQMKde4n61a',
#       'id': '2IDLDx25HU1nQMKde4n61a',
#       'name': 'Rich Brian',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IDLDx25HU1nQMKde4n61a'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7fekFzT8lQv8sZjPGn7JqW'},
#     'href': 'https://api.spotify.com/v1/albums/7fekFzT8lQv8sZjPGn7JqW',
#     'id': '7fekFzT8lQv8sZjPGn7JqW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733c9153fe1cc34dcf27d477aa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023c9153fe1cc34dcf27d477aa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513c9153fe1cc34dcf27d477aa',
#       'width': 64}],
#     'name': '1999',
#     'release_date': '2020-08-25',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:7fekFzT8lQv8sZjPGn7JqW'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 100}}

# %% [markdown]
# ## Task 12: Navigate the dictionary

# %% [markdown]
# Explore the `first_response` dictionary and find how to access the items list, which contains the details about the twenty songs. Assign the list to the variable `first_twenty_songs`.
#
# Hint: print out the keys at each level with .keys().

# %%
# call_on_students(1)

# %%
# Your code here
first_response.keys()
# Out:
# dict_keys(['albums'])

# %%
###how to make a dataframe from the list
first_dict = pd.DataFrame(first_response)
# Out:
#                                                      albums
# href      https://api.spotify.com/v1/browse/new-releases...
# items     [{'album_type': 'single', 'artists': [{'extern...
# limit                                                    20
# next      https://api.spotify.com/v1/browse/new-releases...
# offset                                                    0
# previous                                               None
# total                                                   100

# %%
first_response.keys()
# Out:
# dict_keys(['albums'])

# %%
first_twenty_songs = first_response['albums']['items']

# %%
twenty_songs = pd.DataFrame(first_twenty_songs)
twenty_songs['name']
# Out:
# 0                     Over Now (with The Weeknd)
# 1                  Ice Cream (with Selena Gomez)
# 2                                          Smile
# 3                                ENERGY (Deluxe)
# 4                                Spotify Singles
# 5                                   B4 The Storm
# 6                         CTV3: Cool Tape Vol. 3
# 7                                  Starting Over
# 8     No Ceilings (feat. Lil Wayne & Jay Gwuapo)
# 9                           Why Do You Lie To Me
# 10                                Deep Reverence
# 11                               Una Niña Inútil
# 12                                         Celia
# 13           conversations with myself about you
# 14                                Whole New Mess
# 15                                   Renaissance
# 16                                  Higher Place
# 17                                           rue
# 18                                    Tumbleweed
# 19                                          1999
# Name: name, dtype: object

# %%
len(first_response['albums']['items'])
# Out:
# 20

# %%
first_twenty_songs
# Out:
# [{'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'},
#     'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY',
#     'id': '7CajNmpbOovFoOoasH2HaY',
#     'name': 'Calvin Harris',
#     'type': 'artist',
#     'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3GPiefSRSOxqTrgKJIB7RL'},
#   'href': 'https://api.spotify.com/v1/albums/3GPiefSRSOxqTrgKJIB7RL',
#   'id': '3GPiefSRSOxqTrgKJIB7RL',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e5e19455ff5f76c58048bea8',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e5e19455ff5f76c58048bea8',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e5e19455ff5f76c58048bea8',
#     'width': 64}],
#   'name': 'Over Now (with The Weeknd)',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3GPiefSRSOxqTrgKJIB7RL'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'},
#     'href': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF',
#     'id': '41MozSoPIsD1dJM0CLPjZF',
#     'name': 'BLACKPINK',
#     'type': 'artist',
#     'uri': 'spotify:artist:41MozSoPIsD1dJM0CLPjZF'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#     'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#     'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#     'name': 'Selena Gomez',
#     'type': 'artist',
#     'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#   'available_markets': ['AD',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HN',
#    'HR',
#    'HU',
#    'IE',
#    'IS',
#    'IT',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PL',
#    'PT',
#    'PY',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SI',
#    'SK',
#    'SV',
#    'TN',
#    'UA',
#    'US',
#    'UY',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2VBb4LRcRSACOfJWRUgVZl'},
#   'href': 'https://api.spotify.com/v1/albums/2VBb4LRcRSACOfJWRUgVZl',
#   'id': '2VBb4LRcRSACOfJWRUgVZl',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733709f2400b95a7c6f22a7ee0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023709f2400b95a7c6f22a7ee0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513709f2400b95a7c6f22a7ee0',
#     'width': 64}],
#   'name': 'Ice Cream (with Selena Gomez)',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2VBb4LRcRSACOfJWRUgVZl'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#     'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#     'id': '6jJ0s89eD6GaHleKKya26X',
#     'name': 'Katy Perry',
#     'type': 'artist',
#     'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/47zMF6LrXQ8odi6Xv1unC0'},
#   'href': 'https://api.spotify.com/v1/albums/47zMF6LrXQ8odi6Xv1unC0',
#   'id': '47zMF6LrXQ8odi6Xv1unC0',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735ebe6cbd74a47a5e8ea88985',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025ebe6cbd74a47a5e8ea88985',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515ebe6cbd74a47a5e8ea88985',
#     'width': 64}],
#   'name': 'Smile',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:47zMF6LrXQ8odi6Xv1unC0'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nS5roXSAGhTGr34W6n7Et'},
#     'href': 'https://api.spotify.com/v1/artists/6nS5roXSAGhTGr34W6n7Et',
#     'id': '6nS5roXSAGhTGr34W6n7Et',
#     'name': 'Disclosure',
#     'type': 'artist',
#     'uri': 'spotify:artist:6nS5roXSAGhTGr34W6n7Et'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6wp1us3xBnYz5qldxrZXRf'},
#   'href': 'https://api.spotify.com/v1/albums/6wp1us3xBnYz5qldxrZXRf',
#   'id': '6wp1us3xBnYz5qldxrZXRf',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273355bf68fa788b6d401195b43',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02355bf68fa788b6d401195b43',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851355bf68fa788b6d401195b43',
#     'width': 64}],
#   'name': 'ENERGY (Deluxe)',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:6wp1us3xBnYz5qldxrZXRf'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#     'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#     'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#     'name': 'Giveon',
#     'type': 'artist',
#     'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7pfQDManhpjhxwqps9cveA'},
#   'href': 'https://api.spotify.com/v1/albums/7pfQDManhpjhxwqps9cveA',
#   'id': '7pfQDManhpjhxwqps9cveA',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730043fb835eab4610758979a3',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020043fb835eab4610758979a3',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510043fb835eab4610758979a3',
#     'width': 64}],
#   'name': 'Spotify Singles',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'type': 'album',
#   'uri': 'spotify:album:7pfQDManhpjhxwqps9cveA'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MPCFvOQv5cIGfw3jODMF0'},
#     'href': 'https://api.spotify.com/v1/artists/6MPCFvOQv5cIGfw3jODMF0',
#     'id': '6MPCFvOQv5cIGfw3jODMF0',
#     'name': 'Internet Money',
#     'type': 'artist',
#     'uri': 'spotify:artist:6MPCFvOQv5cIGfw3jODMF0'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0WqVpr3waP7ajONlqa8Fwj'},
#   'href': 'https://api.spotify.com/v1/albums/0WqVpr3waP7ajONlqa8Fwj',
#   'id': '0WqVpr3waP7ajONlqa8Fwj',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27377ddbd0c31707c7308e748a1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0277ddbd0c31707c7308e748a1',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485177ddbd0c31707c7308e748a1',
#     'width': 64}],
#   'name': 'B4 The Storm',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:0WqVpr3waP7ajONlqa8Fwj'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0xOeVMOz2fVg5BJY3N6akT'},
#     'href': 'https://api.spotify.com/v1/artists/0xOeVMOz2fVg5BJY3N6akT',
#     'id': '0xOeVMOz2fVg5BJY3N6akT',
#     'name': 'Jaden',
#     'type': 'artist',
#     'uri': 'spotify:artist:0xOeVMOz2fVg5BJY3N6akT'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2NuZ1TloomufyKf57ZLBQn'},
#   'href': 'https://api.spotify.com/v1/albums/2NuZ1TloomufyKf57ZLBQn',
#   'id': '2NuZ1TloomufyKf57ZLBQn',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273421325b3842bc2f4cf65f1d3',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02421325b3842bc2f4cf65f1d3',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851421325b3842bc2f4cf65f1d3',
#     'width': 64}],
#   'name': 'CTV3: Cool Tape Vol. 3',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:2NuZ1TloomufyKf57ZLBQn'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YLtscXsxbVgi031ovDDdh'},
#     'href': 'https://api.spotify.com/v1/artists/4YLtscXsxbVgi031ovDDdh',
#     'id': '4YLtscXsxbVgi031ovDDdh',
#     'name': 'Chris Stapleton',
#     'type': 'artist',
#     'uri': 'spotify:artist:4YLtscXsxbVgi031ovDDdh'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4AOloVYcXn1aa4p4IhwhRM'},
#   'href': 'https://api.spotify.com/v1/albums/4AOloVYcXn1aa4p4IhwhRM',
#   'id': '4AOloVYcXn1aa4p4IhwhRM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d7d74af20c3a7ac6a0b7a60b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d7d74af20c3a7ac6a0b7a60b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d7d74af20c3a7ac6a0b7a60b',
#     'width': 64}],
#   'name': 'Starting Over',
#   'release_date': '2020-08-27',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4AOloVYcXn1aa4p4IhwhRM'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5dHt1vcEm9qb8fCyLcB3HL'},
#     'href': 'https://api.spotify.com/v1/artists/5dHt1vcEm9qb8fCyLcB3HL',
#     'id': '5dHt1vcEm9qb8fCyLcB3HL',
#     'name': 'A$AP Ferg',
#     'type': 'artist',
#     'uri': 'spotify:artist:5dHt1vcEm9qb8fCyLcB3HL'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7bwhQ4ir83KULY8HnhhpJm'},
#   'href': 'https://api.spotify.com/v1/albums/7bwhQ4ir83KULY8HnhhpJm',
#   'id': '7bwhQ4ir83KULY8HnhhpJm',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734db665e177c24986d3c9992c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024db665e177c24986d3c9992c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514db665e177c24986d3c9992c',
#     'width': 64}],
#   'name': 'No Ceilings (feat. Lil Wayne & Jay Gwuapo)',
#   'release_date': '2020-08-27',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:7bwhQ4ir83KULY8HnhhpJm'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0u6GtibW46tFX7koQ6uNJZ'},
#     'href': 'https://api.spotify.com/v1/artists/0u6GtibW46tFX7koQ6uNJZ',
#     'id': '0u6GtibW46tFX7koQ6uNJZ',
#     'name': 'Topic',
#     'type': 'artist',
#     'uri': 'spotify:artist:0u6GtibW46tFX7koQ6uNJZ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Wg2b4Mp42gicxEeDNawf7'},
#     'href': 'https://api.spotify.com/v1/artists/5Wg2b4Mp42gicxEeDNawf7',
#     'id': '5Wg2b4Mp42gicxEeDNawf7',
#     'name': 'A7S',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Wg2b4Mp42gicxEeDNawf7'}],
#   'available_markets': [],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2u2Cs0hyDvoYayBYEvpRnf'},
#   'href': 'https://api.spotify.com/v1/albums/2u2Cs0hyDvoYayBYEvpRnf',
#   'id': '2u2Cs0hyDvoYayBYEvpRnf',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731ce707b9fe8280a85361c97e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021ce707b9fe8280a85361c97e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511ce707b9fe8280a85361c97e',
#     'width': 64}],
#   'name': 'Why Do You Lie To Me',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2u2Cs0hyDvoYayBYEvpRnf'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0c173mlxpT3dSFRgMO8XPh'},
#     'href': 'https://api.spotify.com/v1/artists/0c173mlxpT3dSFRgMO8XPh',
#     'id': '0c173mlxpT3dSFRgMO8XPh',
#     'name': 'Big Sean',
#     'type': 'artist',
#     'uri': 'spotify:artist:0c173mlxpT3dSFRgMO8XPh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EeQBlQJFiAfJeVN2vT9s0'},
#     'href': 'https://api.spotify.com/v1/artists/0EeQBlQJFiAfJeVN2vT9s0',
#     'id': '0EeQBlQJFiAfJeVN2vT9s0',
#     'name': 'Nipsey Hussle',
#     'type': 'artist',
#     'uri': 'spotify:artist:0EeQBlQJFiAfJeVN2vT9s0'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4RCSDGVMSrMZXgHre4W3oa'},
#   'href': 'https://api.spotify.com/v1/albums/4RCSDGVMSrMZXgHre4W3oa',
#   'id': '4RCSDGVMSrMZXgHre4W3oa',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273ae115d187f0b5dd7ba6751b0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02ae115d187f0b5dd7ba6751b0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851ae115d187f0b5dd7ba6751b0',
#     'width': 64}],
#   'name': 'Deep Reverence',
#   'release_date': '2020-08-25',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4RCSDGVMSrMZXgHre4W3oa'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6w3SkAHYPsQ1bxV7VDlG5y'},
#     'href': 'https://api.spotify.com/v1/artists/6w3SkAHYPsQ1bxV7VDlG5y',
#     'id': '6w3SkAHYPsQ1bxV7VDlG5y',
#     'name': 'Cazzu',
#     'type': 'artist',
#     'uri': 'spotify:artist:6w3SkAHYPsQ1bxV7VDlG5y'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3cOK1UKpkM2v2xtcbNFzzc'},
#   'href': 'https://api.spotify.com/v1/albums/3cOK1UKpkM2v2xtcbNFzzc',
#   'id': '3cOK1UKpkM2v2xtcbNFzzc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273205ac7dee5566c878553d4ea',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02205ac7dee5566c878553d4ea',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851205ac7dee5566c878553d4ea',
#     'width': 64}],
#   'name': 'Una Niña Inútil',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 7,
#   'type': 'album',
#   'uri': 'spotify:album:3cOK1UKpkM2v2xtcbNFzzc'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hNaHKp2Za5YdOAG0WnRbc'},
#     'href': 'https://api.spotify.com/v1/artists/1hNaHKp2Za5YdOAG0WnRbc',
#     'id': '1hNaHKp2Za5YdOAG0WnRbc',
#     'name': 'Tiwa Savage',
#     'type': 'artist',
#     'uri': 'spotify:artist:1hNaHKp2Za5YdOAG0WnRbc'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0v0pKqegGprcnGYUGitYvO'},
#   'href': 'https://api.spotify.com/v1/albums/0v0pKqegGprcnGYUGitYvO',
#   'id': '0v0pKqegGprcnGYUGitYvO',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27325bececcdc7bcade57bec01b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0225bececcdc7bcade57bec01b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485125bececcdc7bcade57bec01b',
#     'width': 64}],
#   'name': 'Celia',
#   'release_date': '2020-08-27',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:0v0pKqegGprcnGYUGitYvO'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4KJ6jujcNPzOyhdNoiNftp'},
#     'href': 'https://api.spotify.com/v1/artists/4KJ6jujcNPzOyhdNoiNftp',
#     'id': '4KJ6jujcNPzOyhdNoiNftp',
#     'name': 'lovelytheband',
#     'type': 'artist',
#     'uri': 'spotify:artist:4KJ6jujcNPzOyhdNoiNftp'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/190bl0MFluUBIYvvheHTw3'},
#   'href': 'https://api.spotify.com/v1/albums/190bl0MFluUBIYvvheHTw3',
#   'id': '190bl0MFluUBIYvvheHTw3',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27321c67d105698f0af4f956f0f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0221c67d105698f0af4f956f0f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485121c67d105698f0af4f956f0f',
#     'width': 64}],
#   'name': 'conversations with myself about you',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:190bl0MFluUBIYvvheHTw3'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mKqFxGMS5TGDZI3XkT5Rt'},
#     'href': 'https://api.spotify.com/v1/artists/6mKqFxGMS5TGDZI3XkT5Rt',
#     'id': '6mKqFxGMS5TGDZI3XkT5Rt',
#     'name': 'Angel Olsen',
#     'type': 'artist',
#     'uri': 'spotify:artist:6mKqFxGMS5TGDZI3XkT5Rt'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6j4BnZet4BZ8YgSUZ3n1cf'},
#   'href': 'https://api.spotify.com/v1/albums/6j4BnZet4BZ8YgSUZ3n1cf',
#   'id': '6j4BnZet4BZ8YgSUZ3n1cf',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273bf7ece51a28e1fe747703443',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02bf7ece51a28e1fe747703443',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851bf7ece51a28e1fe747703443',
#     'width': 64}],
#   'name': 'Whole New Mess',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:6j4BnZet4BZ8YgSUZ3n1cf'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ITI6SEoUZMIXXkzCfr4oE'},
#     'href': 'https://api.spotify.com/v1/artists/5ITI6SEoUZMIXXkzCfr4oE',
#     'id': '5ITI6SEoUZMIXXkzCfr4oE',
#     'name': 'Aluna',
#     'type': 'artist',
#     'uri': 'spotify:artist:5ITI6SEoUZMIXXkzCfr4oE'}],
#   'available_markets': ['AE',
#    'AR',
#    'AU',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'DO',
#    'EC',
#    'GT',
#    'HK',
#    'HN',
#    'ID',
#    'IL',
#    'IN',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'MX',
#    'MY',
#    'NI',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PS',
#    'PY',
#    'QA',
#    'SA',
#    'SG',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY',
#    'VN'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0cFJfTwmx4KOM9zEy9i2nB'},
#   'href': 'https://api.spotify.com/v1/albums/0cFJfTwmx4KOM9zEy9i2nB',
#   'id': '0cFJfTwmx4KOM9zEy9i2nB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735c644b84ee541cd05a67e50f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025c644b84ee541cd05a67e50f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515c644b84ee541cd05a67e50f',
#     'width': 64}],
#   'name': 'Renaissance',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:0cFJfTwmx4KOM9zEy9i2nB'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ryoUS0W8qXokfMxrlJt6O'},
#     'href': 'https://api.spotify.com/v1/artists/4ryoUS0W8qXokfMxrlJt6O',
#     'id': '4ryoUS0W8qXokfMxrlJt6O',
#     'name': 'Skip Marley',
#     'type': 'artist',
#     'uri': 'spotify:artist:4ryoUS0W8qXokfMxrlJt6O'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3LrRzezQmsqxC2eyqVvdAr'},
#   'href': 'https://api.spotify.com/v1/albums/3LrRzezQmsqxC2eyqVvdAr',
#   'id': '3LrRzezQmsqxC2eyqVvdAr',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731e310ac72c0b4221ac8cc6b5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021e310ac72c0b4221ac8cc6b5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511e310ac72c0b4221ac8cc6b5',
#     'width': 64}],
#   'name': 'Higher Place',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 7,
#   'type': 'album',
#   'uri': 'spotify:album:3LrRzezQmsqxC2eyqVvdAr'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uwAm6vQy7kWPS2bciKWx9'},
#     'href': 'https://api.spotify.com/v1/artists/3uwAm6vQy7kWPS2bciKWx9',
#     'id': '3uwAm6vQy7kWPS2bciKWx9',
#     'name': 'girl in red',
#     'type': 'artist',
#     'uri': 'spotify:artist:3uwAm6vQy7kWPS2bciKWx9'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0wwsKyplQfWHtLxlMvVkvP'},
#   'href': 'https://api.spotify.com/v1/albums/0wwsKyplQfWHtLxlMvVkvP',
#   'id': '0wwsKyplQfWHtLxlMvVkvP',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c89027bc69c39397226421e3',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c89027bc69c39397226421e3',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c89027bc69c39397226421e3',
#     'width': 64}],
#   'name': 'rue',
#   'release_date': '2020-08-26',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:0wwsKyplQfWHtLxlMvVkvP'},
#  {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0u2FHSq3ln94y5Q57xazwf'},
#     'href': 'https://api.spotify.com/v1/artists/0u2FHSq3ln94y5Q57xazwf',
#     'id': '0u2FHSq3ln94y5Q57xazwf',
#     'name': 'Keith Urban',
#     'type': 'artist',
#     'uri': 'spotify:artist:0u2FHSq3ln94y5Q57xazwf'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1Q81TJjvwrir41wBsFUSNm'},
#   'href': 'https://api.spotify.com/v1/albums/1Q81TJjvwrir41wBsFUSNm',
#   'id': '1Q81TJjvwrir41wBsFUSNm',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730d2b606f68b28befc35a1114',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020d2b606f68b28befc35a1114',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510d2b606f68b28befc35a1114',
#     'width': 64}],
#   'name': 'Tumbleweed',
#   'release_date': '2020-08-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:1Q81TJjvwrir41wBsFUSNm'},
#  {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IDLDx25HU1nQMKde4n61a'},
#     'href': 'https://api.spotify.com/v1/artists/2IDLDx25HU1nQMKde4n61a',
#     'id': '2IDLDx25HU1nQMKde4n61a',
#     'name': 'Rich Brian',
#     'type': 'artist',
#     'uri': 'spotify:artist:2IDLDx25HU1nQMKde4n61a'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7fekFzT8lQv8sZjPGn7JqW'},
#   'href': 'https://api.spotify.com/v1/albums/7fekFzT8lQv8sZjPGn7JqW',
#   'id': '7fekFzT8lQv8sZjPGn7JqW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733c9153fe1cc34dcf27d477aa',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023c9153fe1cc34dcf27d477aa',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513c9153fe1cc34dcf27d477aa',
#     'width': 64}],
#   'name': '1999',
#   'release_date': '2020-08-25',
#   'release_date_precision': 'day',
#   'total_tracks': 7,
#   'type': 'album',
#   'uri': 'spotify:album:7fekFzT8lQv8sZjPGn7JqW'}]

# %% [markdown]
# ## Task 13: Loop to List

# %% [markdown]
# Create a list of **track names** of all twenty songs using a for loop or list comprehension.

# %%
# call_on_students(1)

# %%
##Option 1 for loop

track_names = []
for songs in first_twenty_songs:
    track_names.append(songs['name'])

track_names
# Out:
# ['Over Now (with The Weeknd)',
#  'Ice Cream (with Selena Gomez)',
#  'Smile',
#  'ENERGY (Deluxe)',
#  'Spotify Singles',
#  'B4 The Storm',
#  'CTV3: Cool Tape Vol. 3',
#  'Starting Over',
#  'No Ceilings (feat. Lil Wayne & Jay Gwuapo)',
#  'Why Do You Lie To Me',
#  'Deep Reverence',
#  'Una Niña Inútil',
#  'Celia',
#  'conversations with myself about you',
#  'Whole New Mess',
#  'Renaissance',
#  'Higher Place',
#  'rue',
#  'Tumbleweed',
#  '1999']

# %%
## Option 2 list comprehension

track_names = [songs['name'] for songs in first_twenty_songs]

# %%
track_names
# Out:
# ['Over Now (with The Weeknd)',
#  'Ice Cream (with Selena Gomez)',
#  'Smile',
#  'ENERGY (Deluxe)',
#  'Spotify Singles',
#  'B4 The Storm',
#  'CTV3: Cool Tape Vol. 3',
#  'Starting Over',
#  'No Ceilings (feat. Lil Wayne & Jay Gwuapo)',
#  'Why Do You Lie To Me',
#  'Deep Reverence',
#  'Una Niña Inútil',
#  'Celia',
#  'conversations with myself about you',
#  'Whole New Mess',
#  'Renaissance',
#  'Higher Place',
#  'rue',
#  'Tumbleweed',
#  '1999']

# %%
# Your code here

# %%
#panda version

# %% [markdown]
# ## Task 14: Create a new dictionary

# %% [markdown]
# Create a dictionary called `song_dictionary` which consists of each track name `string` as a key and a `tuple` of artists associated with each track as a value.

# %%
# call_on_students(1)

# %%
# Your code here:
song_dictionary = {}
for song in first_twenty_songs:
    artist_list = []
    for artist in song['artists']:
        artist_list.append(artist['name'])
    song_dictionary[song['name']] = tuple(artist_list)

# %%
song_dictionary
# Out:
# {'Over Now (with The Weeknd)': ('Calvin Harris', 'The Weeknd'),
#  'Ice Cream (with Selena Gomez)': ('BLACKPINK', 'Selena Gomez'),
#  'Smile': ('Katy Perry',),
#  'ENERGY (Deluxe)': ('Disclosure',),
#  'Spotify Singles': ('Giveon',),
#  'B4 The Storm': ('Internet Money',),
#  'CTV3: Cool Tape Vol. 3': ('Jaden',),
#  'Starting Over': ('Chris Stapleton',),
#  'No Ceilings (feat. Lil Wayne & Jay Gwuapo)': ('A$AP Ferg',),
#  'Why Do You Lie To Me': ('Topic', 'A7S'),
#  'Deep Reverence': ('Big Sean', 'Nipsey Hussle'),
#  'Una Niña Inútil': ('Cazzu',),
#  'Celia': ('Tiwa Savage',),
#  'conversations with myself about you': ('lovelytheband',),
#  'Whole New Mess': ('Angel Olsen',),
#  'Renaissance': ('Aluna',),
#  'Higher Place': ('Skip Marley',),
#  'rue': ('girl in red',),
#  'Tumbleweed': ('Keith Urban',),
#  '1999': ('Rich Brian',)}

# %%
# Your code here - do a for loop and then a dictionary comprehension:

# %%
#for loop version

# %% [markdown]
# ## Task 15: Write a function

# %% [markdown]
# Create a function with takes an **artist name** and the **song_dictionary** as arguments, and returns a `list` of songs written by that artist.

# %%
# call_on_students(1)

# %%
song_dictionary['Over Now (with The Weeknd)']
# Out:
# ('Calvin Harris', 'The Weeknd')

# %%
# Easier to do things outside of a function first
# Let's try for The Weeknd

song_list = []

for song in song_dictionary:
    if "The Weeknd" in song_dictionary[song]:
        song_list.append(song)
song_list
# Out:
# ['Over Now (with The Weeknd)']

# %%
# Your code here

def find_song_by_artist(artist_name, song_dict):
    
    '''
    Parameters:
    arist_name: a string of an artist's name to be used to search the dictionary
    song_dict:  a dictionary of top_twenty songs with song name as keys and a list of 
    artist names as values
    
    Returns:
    A list of songs which the given artist appeared on
    '''
    song_list = []
    for song in song_dict:
        if artist_name in song_dict[song]:
            song_list.append(song)
    return song_list

# %%
# Test the function:
find_song_by_artist('Selena Gomez', song_dictionary)
# Out:
# ['Ice Cream (with Selena Gomez)']
