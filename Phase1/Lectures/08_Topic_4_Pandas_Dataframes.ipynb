# %% [markdown]
# ![pandas](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/2880px-Pandas_logo.svg.png)

# %% [markdown]
# # Objectives

# %% [markdown]
# - Load .csv files into `pandas` DataFrames
# - Describe and manipulate data in Series and DataFrames

# %% [markdown]
# # What is Pandas?
#
# ![I have no idea what I'm doing panda](https://cdn-images-1.medium.com/max/1600/1*oBx032ncOwLmCFX3Epo3Zg.jpeg)
#
# Just kidding - not actual literal pandas.

# %% [markdown]
# Pandas, as [the Anaconda docs](https://docs.anaconda.com/anaconda/packages/py3.7_osx-64/) tell us, offers us "High-performance, easy-to-use data structures and data analysis tools." It's something like "Excel for Python", but it's quite a bit more powerful. The name comes from "panel data", a common way to describe the kind of multidimensional data we'll be working with in certain academic circles (namely, statistics and econometrics) [[Source]](https://www.dlr.de/sc/Portaldata/15/Resources/dokumente/pyhpc2011/submissions/pyhpc2011_submission_9.pdf)
#
# In order to use pandas, we'll need to import it into our notebook first.

# %%
# Import - using the common alias
import pandas as pd

# %% [markdown]
# ## Accessing Data
#
# ![pandas documentation image showcasing the kinds of data it can both read and write to](https://pandas.pydata.org/docs/_images/02_io_readwrite.svg)
#
# [[Image Source]](https://pandas.pydata.org/docs/getting_started/intro_tutorials/02_read_write.html)

# %% [markdown]
# Pandas can access a ton of different data types, including some that should be familiar: CSVs and JSONs! That's right, no more `with` / `open` statements now that we're using pandas!
#
# Most of the time, we'll see CSVs - so let's access a 'toy' data set quickly just to familiarize ourselves with using pandas. There's a heart dataset available in the data folder on this repository - let's read that in.

# %%
# Use read_csv to read in the heart csv file
# Need to assign it to a variable too - let's call this heart_df
heart_df = pd.read_csv('data/heart.csv')

# %% [markdown]
# Find out more about this dataset [here](https://archive.ics.uci.edu/ml/datasets/Statlog+%28Heart%29).

# %% [markdown]
# The output of the `.read_csv()` function is a pandas *DataFrame*, which has a familiar tabaular structure of rows and columns.

# %%
# Let's check this variable out
heart_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# What type is this variable?
type(heart_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## DataFrames and Series

# %% [markdown]
# Two main types of pandas objects are the DataFrame and the Series, the latter being in effect a single column of the former:

# %%
# Let's grab just one column
age_series = heart_df['age']

# %%
age_series
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %% [markdown]
# Notice how we can isolate a column of our DataFrame simply by using square brackets together with the name of the column. We can also access columns as an attribute of the DataFrame - but that only works if the name of the column doesn't have any spaces or weird characters!

# %%
heart_df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
# What type is the column?
type(age_series)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Both Series and DataFrames have an *index* as well:

# %%
heart_df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
age_series.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %% [markdown]
# DataFrames have columns - but a Series is just a single column, so it doesn't have the columns attribute.

# %%
heart_df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_df.keys()
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# This will throw an error!

# %% [markdown]
# Pandas is built on top of NumPy, and we can always access the NumPy array underlying a DataFrame using `.values`.

# %%
heart_df.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %% [markdown]
# ## Basic DataFrame Attributes and Methods

# %% [markdown]
# ### `.head()` : first 5 rows

# %%
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
first_five = heart_df.head()

# %%
first_five
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### `.tail()` : last 5 rows

# %%
heart_df.tail()
heart_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ### `.info()` : information about the columns, including about nulls in those columns

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ### `.describe()` : statistics about the data

# %%
heart_df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# ### `.dtypes` : data types of each column

# %%
heart_df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ### `.shape` : number of rows and columns

# %%
heart_df.shape
# Out:
# (303, 14)

# %% [markdown]
# ### Statistics
#
# We saw them above, in the `.describe`, but we can also calculate statistics by calling them individually.

# %%
# Calculate the mean - for the whole dataframe!
heart_df.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
# Now min
heart_df.min()
# Out:
# age          29.0
# sex           0.0
# cp            0.0
# trestbps     94.0
# chol        126.0
# fbs           0.0
# restecg       0.0
# thalach      71.0
# exang         0.0
# oldpeak       0.0
# slope         0.0
# ca            0.0
# thal          0.0
# target        0.0
# dtype: float64

# %%
# And max
heart_df.max()
# Out:
# age          77.0
# sex           1.0
# cp            3.0
# trestbps    200.0
# chol        564.0
# fbs           1.0
# restecg       2.0
# thalach     202.0
# exang         1.0
# oldpeak       6.2
# slope         2.0
# ca            4.0
# thal          3.0
# target        1.0
# dtype: float64

# %%
#and max
heart_df['age'].min()
# Out:
# 29

# %% [markdown]
# ## Enough With The Small Stuff - Bring On Real Data!
#
# Let's access an open data portal and get some real live data!

# %% [markdown]
# Austin Animal Center Intake Data: https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm/

# %%
# Accessing a CSV from a url
intakes_url = pd.read_csv('https://data.austintexas.gov/resource/wter-evkm.csv') 
intakes_url.head()
# Out:
#   animal_id       name                 datetime                datetime2  \
# 0   A875253        NaN  2023-02-24T09:33:00.000  2023-02-24T09:33:00.000
# 1   A839506       Beau  2023-02-24T08:18:00.000  2023-02-24T08:18:00.000
# 2   A875242  Butterfly  2023-02-24T08:14:00.000  2023-02-24T08:14:00.000
# 3   A875239    A875239  2023-02-24T08:03:00.000  2023-02-24T08:03:00.000
# 4   A839495      Sammy  2023-02-24T00:43:00.000  2023-02-24T00:43:00.000
#
#                           found_location    intake_type intake_condition  \
# 0    5300 Sh 71 Eastbound in Travis (TX)          Stray          Injured
# 1  13705 Fuchs Grove Road in Travis (TX)          Stray          Injured
# 2         6816 Boyce Lane in Travis (TX)  Public Assist           Normal
# 3     4434 Frontier Trail in Austin (TX)          Stray             Sick
# 4    13705 Fuchs Grove Rd in Travis (TX)  Public Assist          Injured
#
#   animal_type sex_upon_intake age_upon_intake                      breed  \
# 0         Dog         Unknown         2 years  Chow Chow/German Shepherd
# 1         Dog   Neutered Male         8 years           Bull Terrier Mix
# 2         Dog   Intact Female          1 year   Jack Russell Terrier Mix
# 3         Dog     Intact Male         2 years        German Shepherd Mix
# 4         Dog   Neutered Male         3 years               Pit Bull Mix
#
#          color
# 0  Black/Black
# 1   Gray/White
# 2  White/Black
# 3    Tan/White
# 4   Gray/White

# %%
# Same as the JSON output from this API endpoint, but different levels of detail for dates!
intakes_url = pd.read_json('https://data.austintexas.gov/resource/wter-evkm.json') 
intakes_url.head()
# Out:
#   animal_id            datetime                datetime2  \
# 0   A875253 2023-02-24 09:33:00  2023-02-24T09:33:00.000
# 1   A839506 2023-02-24 08:18:00  2023-02-24T08:18:00.000
# 2   A875242 2023-02-24 08:14:00  2023-02-24T08:14:00.000
# 3   A875239 2023-02-24 08:03:00  2023-02-24T08:03:00.000
# 4   A839495 2023-02-24 00:43:00  2023-02-24T00:43:00.000
#
#                           found_location    intake_type intake_condition  \
# 0    5300 Sh 71 Eastbound in Travis (TX)          Stray          Injured
# 1  13705 Fuchs Grove Road in Travis (TX)          Stray          Injured
# 2         6816 Boyce Lane in Travis (TX)  Public Assist           Normal
# 3     4434 Frontier Trail in Austin (TX)          Stray             Sick
# 4    13705 Fuchs Grove Rd in Travis (TX)  Public Assist          Injured
#
#   animal_type sex_upon_intake age_upon_intake                      breed  \
# 0         Dog         Unknown         2 years  Chow Chow/German Shepherd
# 1         Dog   Neutered Male         8 years           Bull Terrier Mix
# 2         Dog   Intact Female          1 year   Jack Russell Terrier Mix
# 3         Dog     Intact Male         2 years        German Shepherd Mix
# 4         Dog   Neutered Male         3 years               Pit Bull Mix
#
#          color       name
# 0  Black/Black        NaN
# 1   Gray/White       Beau
# 2  White/Black  Butterfly
# 3    Tan/White    A875239
# 4   Gray/White      Sammy

# %%
# But this is only 1000 rows... website says there's 136K rows!
intakes_url.shape
# Out:
# (1000, 12)

# %%
# It's a limitation of the API - let's just download the data instead
# It's in the data folder
df = pd.read_csv('data/Austin_Animal_Center_Outcomes_022822.csv')
df.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby

# %%
# Now let's explore those earlier attributes and methods on this dataset!
# Check the first 5 rows
df.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby

# %%
# Check the last 5 rows
df.tail()
# Out:
#        Animal ID       Name                DateTime MonthYear Date of Birth  \
# 137092   A850166     Rainey  01/24/2022 06:20:00 PM  Jan 2022    11/19/2021
# 137093   A852031     Noodle  02/28/2022 12:50:00 PM  Feb 2022    02/23/2020
# 137094   A845839    *Carmen  02/28/2022 01:49:00 PM  Feb 2022    05/05/2020
# 137095   A844321  Mia Marie  02/28/2022 01:04:00 PM  Feb 2022    10/15/2013
# 137096   A813933    Lucille  02/28/2022 02:19:00 PM  Feb 2022    12/21/2018
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 137092     Adoption             NaN         Cat      Intact Male
# 137093     Transfer         Partner         Dog    Neutered Male
# 137094     Adoption          Foster         Dog    Spayed Female
# 137095     Adoption          Foster         Dog    Spayed Female
# 137096     Adoption             NaN         Dog    Spayed Female
#
#        Age upon Outcome                          Breed        Color
# 137092         2 months                        Siamese   Seal Point
# 137093          2 years  Pomeranian/Chihuahua Longhair         Buff
# 137094           1 year                   Pit Bull Mix        Brown
# 137095          8 years                       Pit Bull  Black/White
# 137096          3 years               Belgian Malinois  Brown/Black

# %%
# Check the shape
df.shape
# Out:
# (137097, 12)

# %%
# Check the datatypes
df.dtypes
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# MonthYear           object
# Date of Birth       object
# Outcome Type        object
# Outcome Subtype     object
# Animal Type         object
# Sex upon Outcome    object
# Age upon Outcome    object
# Breed               object
# Color               object
# dtype: object

# %%
# Check more general information on the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137097 entries, 0 to 137096
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         137097 non-null  object
#  1   Name              96095 non-null   object
#  2   DateTime          137097 non-null  object
#  3   MonthYear         137097 non-null  object
#  4   Date of Birth     137097 non-null  object
#  5   Outcome Type      137073 non-null  object
#  6   Outcome Subtype   62653 non-null   object
#  7   Animal Type       137097 non-null  object
#  8   Sex upon Outcome  137095 non-null  object
#  9   Age upon Outcome  137092 non-null  object
#  10  Breed             137097 non-null  object
#  11  Color             137097 non-null  object
# dtypes: object(12)
# memory usage: 12.6+ MB

# %%
# Check summary/descriptive statistics on the dataframe
df.describe()
# Out:
#        Animal ID   Name                DateTime MonthYear Date of Birth  \
# count     137097  96095                  137097    137097        137097
# unique    122587  23022                  113939       101          7499
# top      A721033    Max  04/18/2016 12:00:00 AM  Jun 2019    05/01/2016
# freq          33    617                      39      2244           119
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# count        137073           62653      137097           137095
# unique            9              26           5                5
# top        Adoption         Partner         Dog    Neutered Male
# freq          62707           33259       77091            48299
#
#        Age upon Outcome                   Breed        Color
# count            137092                  137097       137097
# unique               53                    2735          617
# top              1 year  Domestic Shorthair Mix  Black/White
# freq              23780                   32387        14315

# %% [markdown]
# #### Any Observations?
#
# - Just shows the 'Year' column - it's the only numeric column!

# %%
# We can run describe on just the string columns! Gives a different kind of output
#THE COLUMN IS NOT YEAR
df.describe(include=[object])
# Out:
#        Animal ID   Name                DateTime MonthYear Date of Birth  \
# count     137097  96095                  137097    137097        137097
# unique    122587  23022                  113939       101          7499
# top      A721033    Max  04/18/2016 12:00:00 AM  Jun 2019    05/01/2016
# freq          33    617                      39      2244           119
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# count        137073           62653      137097           137095
# unique            9              26           5                5
# top        Adoption         Partner         Dog    Neutered Male
# freq          62707           33259       77091            48299
#
#        Age upon Outcome                   Breed        Color
# count            137092                  137097       137097
# unique               53                    2735          617
# top              1 year  Domestic Shorthair Mix  Black/White
# freq              23780                   32387        14315

# %% [markdown]
# #### Any Observations?
#
# - Can see non-null counts, number of uniques, plus the most frequent and how frequent it is
# - Showcases the different kind of useful data you can explore when it's object vs numeric columns

# %% [markdown]
# ## Adding to a DataFrame

# %% [markdown]
# ### Adding Rows

# %% [markdown]
# We have a new animal coming in, captured here in a Python dictionary:

# %%
# Dictionary, where keys match the column names and values are the row values
# Note that the values are list-like - you could easily add more rows by adding to the lists!
next_row = {
    'Animal ID': ['A851755'],
    'Name': ["T'Challa"],
    'DateTime': ['2/28/2022 11:25:00 AM'],
    'MonthYear': [2022],
    'Found Location': ['Houston (TX)'],
    'Intake Type': ['Public Assist'],
    'Intake Condition': ['Normal'],
    'Animal Type': ['Cat'],
    'Sex upon Intake': ['Neutered Male'],
    'Age upon Intake': ['4 years'],
    'Breed': ['Domestic Shorthair'],
    'Color': ['Black']
}
next_row
# Out:
# {'Animal ID': ['A851755'],
#  'Name': ["T'Challa"],
#  'DateTime': ['2/28/2022 11:25:00 AM'],
#  'Year': [2022],
#  'Found Location': ['Houston (TX)'],
#  'Intake Type': ['Public Assist'],
#  'Intake Condition': ['Normal'],
#  'Animal Type': ['Cat'],
#  'Sex upon Intake': ['Neutered Male'],
#  'Age upon Intake': ['4 years'],
#  'Breed': ['Domestic Shorthair'],
#  'Color': ['Black']}

# %% [markdown]
# How can we add this to the bottom of our dataset?

# %%
# Let's first turn this into a DataFrame.
# We can use the .from_dict() method.
new2 = pd.DataFrame(next_row)
new2
# Out:
#   Animal ID      Name               DateTime  Year Found Location  \
# 0   A851755  T'Challa  2/28/2022 11:25:00 AM  2022   Houston (TX)
#
#      Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0  Public Assist           Normal         Cat   Neutered Male         4 years
#
#                 Breed  Color
# 0  Domestic Shorthair  Black

# %%
# Now we just need to concatenate the two DataFrames together.
# Note the `ignore_index` parameter! We'll set that to True.

df_augmented = pd.concat([df,new2], ignore_index=True)

# %%
# Let's check the end to make sure we were successful!
df_augmented.tail()
# Out:
#        Animal ID       Name                DateTime MonthYear Date of Birth  \
# 137093   A852031     Noodle  02/28/2022 12:50:00 PM  Feb 2022    02/23/2020
# 137094   A845839    *Carmen  02/28/2022 01:49:00 PM  Feb 2022    05/05/2020
# 137095   A844321  Mia Marie  02/28/2022 01:04:00 PM  Feb 2022    10/15/2013
# 137096   A813933    Lucille  02/28/2022 02:19:00 PM  Feb 2022    12/21/2018
# 137097   A851755   T'Challa   2/28/2022 11:25:00 AM       NaN           NaN
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 137093     Transfer         Partner         Dog    Neutered Male
# 137094     Adoption          Foster         Dog    Spayed Female
# 137095     Adoption          Foster         Dog    Spayed Female
# 137096     Adoption             NaN         Dog    Spayed Female
# 137097          NaN             NaN         Cat              NaN
#
#        Age upon Outcome                          Breed        Color    Year  \
# 137093          2 years  Pomeranian/Chihuahua Longhair         Buff     NaN
# 137094           1 year                   Pit Bull Mix        Brown     NaN
# 137095          8 years                       Pit Bull  Black/White     NaN
# 137096          3 years               Belgian Malinois  Brown/Black     NaN
# 137097              NaN             Domestic Shorthair        Black  2022.0
#
#        Found Location    Intake Type Intake Condition Sex upon Intake  \
# 137093            NaN            NaN              NaN             NaN
# 137094            NaN            NaN              NaN             NaN
# 137095            NaN            NaN              NaN             NaN
# 137096            NaN            NaN              NaN             NaN
# 137097   Houston (TX)  Public Assist           Normal   Neutered Male
#
#        Age upon Intake
# 137093             NaN
# 137094             NaN
# 137095             NaN
# 137096             NaN
# 137097         4 years

# %% [markdown]
# ### Adding (and Deleting) Columns

# %% [markdown]
# Adding a column is very easy in `pandas`. Let's add a new column to our dataset called "test", and set all of its values to 0.

# %%
# Create a new column, 'test', where every value in the col is 0
df_augmented['test'] = 0

# %%
# Sanity check
df_augmented.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Year Found Location  \
# 0              Domestic Shorthair Mix  Brown Tabby/White   NaN            NaN
# 1             Chihuahua Shorthair Mix        White/Brown   NaN            NaN
# 2                             Raccoon               Gray   NaN            NaN
# 3  Anatol Shepherd/Labrador Retriever               Buff   NaN            NaN
# 4              Domestic Shorthair Mix       Orange Tabby   NaN            NaN
#
#   Intake Type Intake Condition Sex upon Intake Age upon Intake  test
# 0         NaN              NaN             NaN             NaN     0
# 1         NaN              NaN             NaN             NaN     0
# 2         NaN              NaN             NaN             NaN     0
# 3         NaN              NaN             NaN             NaN     0
# 4         NaN              NaN             NaN             NaN     0

# %% [markdown]
# But we don't need that - let's drop that column.

# %%
# Drop that test column
df_augmented.drop(columns=['test'])
# Out:
#        Animal ID       Name                DateTime MonthYear Date of Birth  \
# 0        A794011      Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1        A776359      Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2        A821648        NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3        A720371      Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4        A674754        NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
# ...          ...        ...                     ...       ...           ...
# 137093   A852031     Noodle  02/28/2022 12:50:00 PM  Feb 2022    02/23/2020
# 137094   A845839    *Carmen  02/28/2022 01:49:00 PM  Feb 2022    05/05/2020
# 137095   A844321  Mia Marie  02/28/2022 01:04:00 PM  Feb 2022    10/15/2013
# 137096   A813933    Lucille  02/28/2022 02:19:00 PM  Feb 2022    12/21/2018
# 137097   A851755   T'Challa   2/28/2022 11:25:00 AM       NaN           NaN
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0         Rto-Adopt             NaN         Cat    Neutered Male
# 1          Adoption             NaN         Dog    Neutered Male
# 2        Euthanasia             NaN       Other          Unknown
# 3          Adoption             NaN         Dog    Neutered Male
# 4          Transfer         Partner         Cat      Intact Male
# ...             ...             ...         ...              ...
# 137093     Transfer         Partner         Dog    Neutered Male
# 137094     Adoption          Foster         Dog    Spayed Female
# 137095     Adoption          Foster         Dog    Spayed Female
# 137096     Adoption             NaN         Dog    Spayed Female
# 137097          NaN             NaN         Cat              NaN
#
#        Age upon Outcome                               Breed  \
# 0               2 years              Domestic Shorthair Mix
# 1                1 year             Chihuahua Shorthair Mix
# 2                1 year                             Raccoon
# 3              4 months  Anatol Shepherd/Labrador Retriever
# 4                6 days              Domestic Shorthair Mix
# ...                 ...                                 ...
# 137093          2 years       Pomeranian/Chihuahua Longhair
# 137094           1 year                        Pit Bull Mix
# 137095          8 years                            Pit Bull
# 137096          3 years                    Belgian Malinois
# 137097              NaN                  Domestic Shorthair
#
#                     Color    Year Found Location    Intake Type  \
# 0       Brown Tabby/White     NaN            NaN            NaN
# 1             White/Brown     NaN            NaN            NaN
# 2                    Gray     NaN            NaN            NaN
# 3                    Buff     NaN            NaN            NaN
# 4            Orange Tabby     NaN            NaN            NaN
# ...                   ...     ...            ...            ...
# 137093               Buff     NaN            NaN            NaN
# 137094              Brown     NaN            NaN            NaN
# 137095        Black/White     NaN            NaN            NaN
# 137096        Brown/Black     NaN            NaN            NaN
# 137097              Black  2022.0   Houston (TX)  Public Assist
#
#        Intake Condition Sex upon Intake Age upon Intake
# 0                   NaN             NaN             NaN
# 1                   NaN             NaN             NaN
# 2                   NaN             NaN             NaN
# 3                   NaN             NaN             NaN
# 4                   NaN             NaN             NaN
# ...                 ...             ...             ...
# 137093              NaN             NaN             NaN
# 137094              NaN             NaN             NaN
# 137095              NaN             NaN             NaN
# 137096              NaN             NaN             NaN
# 137097           Normal   Neutered Male         4 years
#
# [137098 rows x 18 columns]

# %%
# Alternate way using axis arguement
df_augmented.drop('test', axis=1)
# Out:
#        Animal ID       Name                DateTime MonthYear Date of Birth  \
# 0        A794011      Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1        A776359      Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2        A821648        NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3        A720371      Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4        A674754        NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
# ...          ...        ...                     ...       ...           ...
# 137093   A852031     Noodle  02/28/2022 12:50:00 PM  Feb 2022    02/23/2020
# 137094   A845839    *Carmen  02/28/2022 01:49:00 PM  Feb 2022    05/05/2020
# 137095   A844321  Mia Marie  02/28/2022 01:04:00 PM  Feb 2022    10/15/2013
# 137096   A813933    Lucille  02/28/2022 02:19:00 PM  Feb 2022    12/21/2018
# 137097   A851755   T'Challa   2/28/2022 11:25:00 AM       NaN           NaN
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0         Rto-Adopt             NaN         Cat    Neutered Male
# 1          Adoption             NaN         Dog    Neutered Male
# 2        Euthanasia             NaN       Other          Unknown
# 3          Adoption             NaN         Dog    Neutered Male
# 4          Transfer         Partner         Cat      Intact Male
# ...             ...             ...         ...              ...
# 137093     Transfer         Partner         Dog    Neutered Male
# 137094     Adoption          Foster         Dog    Spayed Female
# 137095     Adoption          Foster         Dog    Spayed Female
# 137096     Adoption             NaN         Dog    Spayed Female
# 137097          NaN             NaN         Cat              NaN
#
#        Age upon Outcome                               Breed  \
# 0               2 years              Domestic Shorthair Mix
# 1                1 year             Chihuahua Shorthair Mix
# 2                1 year                             Raccoon
# 3              4 months  Anatol Shepherd/Labrador Retriever
# 4                6 days              Domestic Shorthair Mix
# ...                 ...                                 ...
# 137093          2 years       Pomeranian/Chihuahua Longhair
# 137094           1 year                        Pit Bull Mix
# 137095          8 years                            Pit Bull
# 137096          3 years                    Belgian Malinois
# 137097              NaN                  Domestic Shorthair
#
#                     Color    Year Found Location    Intake Type  \
# 0       Brown Tabby/White     NaN            NaN            NaN
# 1             White/Brown     NaN            NaN            NaN
# 2                    Gray     NaN            NaN            NaN
# 3                    Buff     NaN            NaN            NaN
# 4            Orange Tabby     NaN            NaN            NaN
# ...                   ...     ...            ...            ...
# 137093               Buff     NaN            NaN            NaN
# 137094              Brown     NaN            NaN            NaN
# 137095        Black/White     NaN            NaN            NaN
# 137096        Brown/Black     NaN            NaN            NaN
# 137097              Black  2022.0   Houston (TX)  Public Assist
#
#        Intake Condition Sex upon Intake Age upon Intake
# 0                   NaN             NaN             NaN
# 1                   NaN             NaN             NaN
# 2                   NaN             NaN             NaN
# 3                   NaN             NaN             NaN
# 4                   NaN             NaN             NaN
# ...                 ...             ...             ...
# 137093              NaN             NaN             NaN
# 137094              NaN             NaN             NaN
# 137095              NaN             NaN             NaN
# 137096              NaN             NaN             NaN
# 137097           Normal   Neutered Male         4 years
#
# [137098 rows x 18 columns]

# %%
# Sanity check
df_augmented.head()

# %% [markdown]
# We can also do math with columns, or use mathematical notation to combine columns even when they aren't numerical!
#
# We don't have any numeric data in this current dataset. But we can still create a combined "Type" column that combines the values of our Intake Type and Animal Type columns.

# %%
# Create a new column, 'Type', from the two 'Type' columns
df_augmented['Type'] = df_augmented['Intake Type'] + " " + df_augmented['Animal Type']

# %%
# Sanity check
df_augmented.head()
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3   A720371  Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4   A674754    NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
# 3     Adoption             NaN         Dog    Neutered Male         4 months
# 4     Transfer         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  Year Found Location  \
# 0              Domestic Shorthair Mix  Brown Tabby/White   NaN            NaN
# 1             Chihuahua Shorthair Mix        White/Brown   NaN            NaN
# 2                             Raccoon               Gray   NaN            NaN
# 3  Anatol Shepherd/Labrador Retriever               Buff   NaN            NaN
# 4              Domestic Shorthair Mix       Orange Tabby   NaN            NaN
#
#   Intake Type Intake Condition Sex upon Intake Age upon Intake  test Type
# 0         NaN              NaN             NaN             NaN     0  NaN
# 1         NaN              NaN             NaN             NaN     0  NaN
# 2         NaN              NaN             NaN             NaN     0  NaN
# 3         NaN              NaN             NaN             NaN     0  NaN
# 4         NaN              NaN             NaN             NaN     0  NaN

# %% [markdown]
# ## Filtering

# %% [markdown]
# We can use filtering techniques to see only certain rows of our data. Let's look at only animals taken into the center during or after 2020:

# %%
# Check which rows have an intake year greater than or equal to 2020
df_augmented['Animal Type'] == 'Cat'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 137093    False
# 137094    False
# 137095    False
# 137096    False
# 137097     True
# Name: Animal Type, Length: 137098, dtype: bool

# %%
# Let's explore an interesting property of boolean columns...
# Find out the total sum of animals taken in during or after 2020
sum(df_augmented['Animal Type'] == 'Cat')
# Out:
# 52093

# %% [markdown]
# But this only gives us True/False outputs... what if we want to really filter?

# %% [markdown]
# ### `.loc`

# %% [markdown]
# We can locate and segment down to only rows where some condition is true using `.loc`. This takes in a condition, and only outputs the rows where that condition is True!
#
# > **Note:** locate (`.loc`) uses square brackets, not parentheses! Often, square brackets denote location-focused actions, like this one.
#
# Let's try this first with the condition we just built, and locate all animals taken in during or after 2020.

# %%
# Create a subset dataframe of animals taken in during or after 2020
subset_cat = df_augmented.loc[df_augmented['Animal Type'] == 'Cat']

# %%
subset_cat.head()
# Out:
#    Animal ID        Name                DateTime MonthYear Date of Birth  \
# 0    A794011       Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 4    A674754         NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
# 7    A689724  *Donatello  10/18/2014 06:52:00 PM  Oct 2014    08/01/2014
# 8    A680969       *Zeus  08/05/2014 04:59:00 PM  Aug 2014    06/03/2014
# 10   A684617         NaN  07/27/2014 09:00:00 AM  Jul 2014    07/26/2012
#
#    Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0     Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 4      Transfer         Partner         Cat      Intact Male           6 days
# 7      Adoption             NaN         Cat    Neutered Male         2 months
# 8      Adoption             NaN         Cat    Neutered Male         2 months
# 10     Transfer            SCRP         Cat    Intact Female          2 years
#
#                      Breed               Color  Year Found Location  \
# 0   Domestic Shorthair Mix   Brown Tabby/White   NaN            NaN
# 4   Domestic Shorthair Mix        Orange Tabby   NaN            NaN
# 7   Domestic Shorthair Mix               Black   NaN            NaN
# 8   Domestic Shorthair Mix  White/Orange Tabby   NaN            NaN
# 10  Domestic Shorthair Mix               Black   NaN            NaN
#
#    Intake Type Intake Condition Sex upon Intake Age upon Intake  test Type
# 0          NaN              NaN             NaN             NaN     0  NaN
# 4          NaN              NaN             NaN             NaN     0  NaN
# 7          NaN              NaN             NaN             NaN     0  NaN
# 8          NaN              NaN             NaN             NaN     0  NaN
# 10         NaN              NaN             NaN             NaN     0  NaN

# %% [markdown]
# We can return only certain columns when we do this, by adding an argument after the condition:

# %%
# Let's return just the 'Animal ID', 'DateTime' and 'Type' columns
subset_cat2 = df_augmented.loc[df_augmented['Animal Type'] == 'Cat',['Animal ID','Intake Type','Color']]
subset_cat2
# Out:
#        Animal ID    Intake Type               Color
# 0        A794011            NaN   Brown Tabby/White
# 4        A674754            NaN        Orange Tabby
# 7        A689724            NaN               Black
# 8        A680969            NaN  White/Orange Tabby
# 10       A684617            NaN               Black
# ...          ...            ...                 ...
# 137086   A852166            NaN   Brown Tabby/White
# 137088   A851184            NaN  Orange Tabby/White
# 137090   A847804            NaN   Brown Tabby/White
# 137092   A850166            NaN          Seal Point
# 137097   A851755  Public Assist               Black
#
# [52093 rows x 3 columns]

# %% [markdown]
# What if I want to segment using multiple conditions? Use `&` for "and" and `|` for "or" - and use parentheses around individual conditions!

# %%
# Find all the Stray Cats taken in during or after 2020
df_augmented.loc[(df_augmented['Animal Type'] == 'Cat') & (df_augmented['Color'] == 'Black')]
# Out:
#        Animal ID          Name                DateTime MonthYear  \
# 7        A689724    *Donatello  10/18/2014 06:52:00 PM  Oct 2014
# 10       A684617           NaN  07/27/2014 09:00:00 AM  Jul 2014
# 67       A696409         *Hans  02/09/2015 06:46:00 PM  Feb 2015
# 83       A783412         *Yams  12/16/2018 12:45:00 PM  Dec 2018
# 157      A662741         *Todd  10/05/2013 12:42:00 PM  Oct 2013
# ...          ...           ...                     ...       ...
# 136970   A851776        *Frito  02/23/2022 05:54:00 PM  Feb 2022
# 137048   A800430          Joey  02/26/2022 07:56:00 AM  Feb 2022
# 137074   A852015           NaN  02/27/2022 08:17:00 AM  Feb 2022
# 137079   A852023  *Rain Shadow  02/28/2022 09:48:00 AM  Feb 2022
# 137097   A851755      T'Challa   2/28/2022 11:25:00 AM       NaN
#
#        Date of Birth Outcome Type Outcome Subtype Animal Type  \
# 7         08/01/2014     Adoption             NaN         Cat
# 10        07/26/2012     Transfer            SCRP         Cat
# 67        11/19/2014     Adoption             NaN         Cat
# 83        10/30/2008     Adoption             NaN         Cat
# 157       08/11/2013     Transfer         Partner         Cat
# ...              ...          ...             ...         ...
# 136970    02/18/2021     Adoption             NaN         Cat
# 137048    07/21/2014     Adoption          Foster         Cat
# 137074    02/23/2020         Died       Emergency         Cat
# 137079    10/23/2021     Transfer             Snr         Cat
# 137097           NaN          NaN             NaN         Cat
#
#        Sex upon Outcome Age upon Outcome                     Breed  Color  \
# 7         Neutered Male         2 months    Domestic Shorthair Mix  Black
# 10        Intact Female          2 years    Domestic Shorthair Mix  Black
# 67        Neutered Male         2 months    Domestic Shorthair Mix  Black
# 83        Neutered Male         10 years    Domestic Shorthair Mix  Black
# 157         Intact Male          1 month    Domestic Shorthair Mix  Black
# ...                 ...              ...                       ...    ...
# 136970    Neutered Male           1 year  Domestic Medium Hair Mix  Black
# 137048    Neutered Male          7 years      Domestic Medium Hair  Black
# 137074          Unknown          2 years        Domestic Shorthair  Black
# 137079          Unknown         4 months        Domestic Shorthair  Black
# 137097              NaN              NaN        Domestic Shorthair  Black
#
#           Year Found Location    Intake Type Intake Condition Sex upon Intake  \
# 7          NaN            NaN            NaN              NaN             NaN
# 10         NaN            NaN            NaN              NaN             NaN
# 67         NaN            NaN            NaN              NaN             NaN
# 83         NaN            NaN            NaN              NaN             NaN
# 157        NaN            NaN            NaN              NaN             NaN
# ...        ...            ...            ...              ...             ...
# 136970     NaN            NaN            NaN              NaN             NaN
# 137048     NaN            NaN            NaN              NaN             NaN
# 137074     NaN            NaN            NaN              NaN             NaN
# 137079     NaN            NaN            NaN              NaN             NaN
# 137097  2022.0   Houston (TX)  Public Assist           Normal   Neutered Male
#
#        Age upon Intake  test               Type
# 7                  NaN     0                NaN
# 10                 NaN     0                NaN
# 67                 NaN     0                NaN
# 83                 NaN     0                NaN
# 157                NaN     0                NaN
# ...                ...   ...                ...
# 136970             NaN     0                NaN
# 137048             NaN     0                NaN
# 137074             NaN     0                NaN
# 137079             NaN     0                NaN
# 137097         4 years     0  Public Assist Cat
#
# [6829 rows x 20 columns]

# %% [markdown]
# ## Your turn!

# %% [markdown]
# ### Exercise 1
#
# You need to find dogs that need extra attention - How would you find all dogs where the intake condition is NOT normal?

# %%
# Your code here

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#
# ```python
# df_augmented.loc[(df_augmented['Animal Type'] == 'Dog') & (df_augmented['Intake Condition'] != 'Normal')]
# ```
# </details>

# %% [markdown]
# ### Exercise 2
#
# You need to find animals that might need to be fixed - How would you find all animals that are either Intact Male or Intact Female?

# %%
# Your code here
df_augmented.iloc[:]
# Out:
#        Animal ID       Name                DateTime MonthYear Date of Birth  \
# 0        A794011      Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1        A776359      Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2        A821648        NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3        A720371      Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4        A674754        NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
# ...          ...        ...                     ...       ...           ...
# 137093   A852031     Noodle  02/28/2022 12:50:00 PM  Feb 2022    02/23/2020
# 137094   A845839    *Carmen  02/28/2022 01:49:00 PM  Feb 2022    05/05/2020
# 137095   A844321  Mia Marie  02/28/2022 01:04:00 PM  Feb 2022    10/15/2013
# 137096   A813933    Lucille  02/28/2022 02:19:00 PM  Feb 2022    12/21/2018
# 137097   A851755   T'Challa   2/28/2022 11:25:00 AM       NaN           NaN
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0         Rto-Adopt             NaN         Cat    Neutered Male
# 1          Adoption             NaN         Dog    Neutered Male
# 2        Euthanasia             NaN       Other          Unknown
# 3          Adoption             NaN         Dog    Neutered Male
# 4          Transfer         Partner         Cat      Intact Male
# ...             ...             ...         ...              ...
# 137093     Transfer         Partner         Dog    Neutered Male
# 137094     Adoption          Foster         Dog    Spayed Female
# 137095     Adoption          Foster         Dog    Spayed Female
# 137096     Adoption             NaN         Dog    Spayed Female
# 137097          NaN             NaN         Cat              NaN
#
#        Age upon Outcome                               Breed  \
# 0               2 years              Domestic Shorthair Mix
# 1                1 year             Chihuahua Shorthair Mix
# 2                1 year                             Raccoon
# 3              4 months  Anatol Shepherd/Labrador Retriever
# 4                6 days              Domestic Shorthair Mix
# ...                 ...                                 ...
# 137093          2 years       Pomeranian/Chihuahua Longhair
# 137094           1 year                        Pit Bull Mix
# 137095          8 years                            Pit Bull
# 137096          3 years                    Belgian Malinois
# 137097              NaN                  Domestic Shorthair
#
#                     Color    Year Found Location    Intake Type  \
# 0       Brown Tabby/White     NaN            NaN            NaN
# 1             White/Brown     NaN            NaN            NaN
# 2                    Gray     NaN            NaN            NaN
# 3                    Buff     NaN            NaN            NaN
# 4            Orange Tabby     NaN            NaN            NaN
# ...                   ...     ...            ...            ...
# 137093               Buff     NaN            NaN            NaN
# 137094              Brown     NaN            NaN            NaN
# 137095        Black/White     NaN            NaN            NaN
# 137096        Brown/Black     NaN            NaN            NaN
# 137097              Black  2022.0   Houston (TX)  Public Assist
#
#        Intake Condition Sex upon Intake Age upon Intake  test  \
# 0                   NaN             NaN             NaN     0
# 1                   NaN             NaN             NaN     0
# 2                   NaN             NaN             NaN     0
# 3                   NaN             NaN             NaN     0
# 4                   NaN             NaN             NaN     0
# ...                 ...             ...             ...   ...
# 137093              NaN             NaN             NaN     0
# 137094              NaN             NaN             NaN     0
# 137095              NaN             NaN             NaN     0
# 137096              NaN             NaN             NaN     0
# 137097           Normal   Neutered Male         4 years     0
#
#                      Type
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 137093                NaN
# 137094                NaN
# 137095                NaN
# 137096                NaN
# 137097  Public Assist Cat
#
# [137098 rows x 20 columns]

# %% [markdown]
# <details>
#     <summary>Answer</summary>
#
# ```python
# df_augmented[(df_augmented['Sex upon Intake'] == 'Intact Male') |
#              (df_augmented['Sex upon Intake'] == 'Intact Female')]
# ```
# </details>

# %% [markdown]
# ### `.iloc`

# %% [markdown]
# `.iloc` is used for integer-location based indexing, aka locate by number. It can take in lists of numbers, python slices, or specific numbers - but sometimes it can be a bit tricky!

# %%
# Find the first 3 rows
df_augmented.iloc[0:3]
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
#
#                      Breed              Color  Year Found Location  \
# 0   Domestic Shorthair Mix  Brown Tabby/White   NaN            NaN
# 1  Chihuahua Shorthair Mix        White/Brown   NaN            NaN
# 2                  Raccoon               Gray   NaN            NaN
#
#   Intake Type Intake Condition Sex upon Intake Age upon Intake  test Type
# 0         NaN              NaN             NaN             NaN     0  NaN
# 1         NaN              NaN             NaN             NaN     0  NaN
# 2         NaN              NaN             NaN             NaN     0  NaN

# %%
# Same as using head(3)
df_augmented.head(3)
# Out:
#   Animal ID   Name                DateTime MonthYear Date of Birth  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2   A821648    NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 1     Adoption             NaN         Dog    Neutered Male           1 year
# 2   Euthanasia             NaN       Other          Unknown           1 year
#
#                      Breed              Color  Year Found Location  \
# 0   Domestic Shorthair Mix  Brown Tabby/White   NaN            NaN
# 1  Chihuahua Shorthair Mix        White/Brown   NaN            NaN
# 2                  Raccoon               Gray   NaN            NaN
#
#   Intake Type Intake Condition Sex upon Intake Age upon Intake  test Type
# 0         NaN              NaN             NaN             NaN     0  NaN
# 1         NaN              NaN             NaN             NaN     0  NaN
# 2         NaN              NaN             NaN             NaN     0  NaN

# %%
# Can look exactly where the 0 index is

# %%
# But what about our subset dataframe above? It doesn't have an index 0
subset_cat.head()

# %%
# Try it...
subset_cat.iloc[0]
# Out:
# Animal ID                          A794011
# Name                                 Chunk
# DateTime            05/08/2019 06:20:00 PM
# MonthYear                         May 2019
# Date of Birth                   05/02/2017
# Outcome Type                     Rto-Adopt
# Outcome Subtype                        NaN
# Animal Type                            Cat
# Sex upon Outcome             Neutered Male
# Age upon Outcome                   2 years
# Breed               Domestic Shorthair Mix
# Color                    Brown Tabby/White
# Year                                   NaN
# Found Location                         NaN
# Intake Type                            NaN
# Intake Condition                       NaN
# Sex upon Intake                        NaN
# Age upon Intake                        NaN
# test                                     0
# Type                                   NaN
# Name: 0, dtype: object

# %% [markdown]
# ## Series Methods

# %% [markdown]
# ### `.value_counts()`

# %% [markdown]
# How many different values does the Animal Type column have? What about Breed?

# %%
# Check the value counts for Animal Type
df_augmented['Animal Type'].value_counts()
# Out:
# Dog          77091
# Cat          52093
# Other         7253
# Bird           636
# Livestock       25
# Name: Animal Type, dtype: int64

# %%
# Now check Breed
df_augmented['Breed'].value_counts()
# Out:
# Domestic Shorthair Mix              32387
# Domestic Shorthair                  10365
# Pit Bull Mix                         8937
# Labrador Retriever Mix               7397
# Chihuahua Shorthair Mix              6518
#                                     ...
# Blue Lacy/Basset Hound                  1
# Bluetick Hound/Australian Kelpie        1
# Belgian Hare                            1
# Swiss Hound Mix                         1
# Australian Shepherd/Beagle              1
# Name: Breed, Length: 2735, dtype: int64

# %% [markdown]
# Sometimes, this is more useful than others... but, can check the percentage of the total, which might be more useful!

# %%
# Use the normalize argument to change how the count is displayed
df_augmented['Animal Type'].value_counts(normalize=True)
# Out:
# Dog          0.562306
# Cat          0.379969
# Other        0.052904
# Bird         0.004639
# Livestock    0.000182
# Name: Animal Type, dtype: float64

# %% [markdown]
# ### `.sort_values()`
#
# As you can imagine, this works differently whether you're using it on a numeric or non-numeric column

# %%
# Let's sort the year column

# %%
# Now, sort the Animal Type col
df_augmented['Animal Type'].sort_values()
# Out:
# 81093      Bird
# 86254      Bird
# 65348      Bird
# 122172     Bird
# 60452      Bird
#           ...
# 117408    Other
# 106416    Other
# 82089     Other
# 96760     Other
# 32949     Other
# Name: Animal Type, Length: 137098, dtype: object

# %%
# We can do this on the whole dataframe, it just needs to know what to sort by
# We can always choose ascending or descending
sorted_df = df_augmented.sort_values(by='Animal Type')
sorted_df
# Out:
#        Animal ID    Name                DateTime MonthYear Date of Birth  \
# 81093    A818041     NaN  06/09/2020 09:47:00 PM  Jun 2020    05/31/2019
# 86254    A739191  Prince  11/29/2016 06:03:00 PM  Nov 2016    11/29/2015
# 65348    A719013     NaN  01/17/2016 06:01:00 PM  Jan 2016    01/11/2014
# 122172   A770612     NaN  04/26/2018 07:08:00 PM  Apr 2018    04/22/2017
# 60452    A778193     NaN  08/26/2018 03:43:00 PM  Aug 2018    08/09/2017
# ...          ...     ...                     ...       ...           ...
# 117408   A766860     NaN  02/20/2018 09:10:00 AM  Feb 2018    02/18/2015
# 106416   A791924     NaN  04/03/2019 03:05:00 PM  Apr 2019    04/03/2018
# 82089    A670713     NaN  01/12/2014 05:56:00 PM  Jan 2014    01/12/2011
# 96760    A819484     NaN  06/29/2020 05:13:00 PM  Jun 2020    06/29/2018
# 32949    A745157     NaN  03/13/2017 05:13:00 PM  Mar 2017    03/13/2013
#
#            Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 81093          Adoption             NaN        Bird      Intact Male
# 86254   Return to Owner             NaN        Bird      Intact Male
# 65348        Euthanasia       Suffering        Bird          Unknown
# 122172         Adoption             NaN        Bird          Unknown
# 60452          Transfer         Partner        Bird      Intact Male
# ...                 ...             ...         ...              ...
# 117408       Euthanasia     Rabies Risk       Other          Unknown
# 106416       Euthanasia     Rabies Risk       Other          Unknown
# 82089        Euthanasia     Rabies Risk       Other          Unknown
# 96760        Euthanasia       Suffering       Other          Unknown
# 32949        Euthanasia     Rabies Risk       Other          Unknown
#
#        Age upon Outcome          Breed         Color  Year Found Location  \
# 81093            1 year        Chicken     White/Red   NaN            NaN
# 86254            1 year     Turkey Mix     Black/Red   NaN            NaN
# 65348           2 years           Hawk  Brown/Yellow   NaN            NaN
# 122172           1 year  Cockatiel Mix   Gray/Yellow   NaN            NaN
# 60452            1 year         Bantam      Tricolor   NaN            NaN
# ...                 ...            ...           ...   ...            ...
# 117408          3 years        Bat Mix         Brown   NaN            NaN
# 106416           1 year        Bat Mix         Brown   NaN            NaN
# 82089           3 years            Bat   Brown/Black   NaN            NaN
# 96760           2 years        Raccoon    Gray/Black   NaN            NaN
# 32949           4 years        Bat Mix         Brown   NaN            NaN
#
#        Intake Type Intake Condition Sex upon Intake Age upon Intake  test Type
# 81093          NaN              NaN             NaN             NaN     0  NaN
# 86254          NaN              NaN             NaN             NaN     0  NaN
# 65348          NaN              NaN             NaN             NaN     0  NaN
# 122172         NaN              NaN             NaN             NaN     0  NaN
# 60452          NaN              NaN             NaN             NaN     0  NaN
# ...            ...              ...             ...             ...   ...  ...
# 117408         NaN              NaN             NaN             NaN     0  NaN
# 106416         NaN              NaN             NaN             NaN     0  NaN
# 82089          NaN              NaN             NaN             NaN     0  NaN
# 96760          NaN              NaN             NaN             NaN     0  NaN
# 32949          NaN              NaN             NaN             NaN     0  NaN
#
# [137098 rows x 20 columns]

# %% [markdown]
# # Extra Credit: Find a .csv file online and experiment with it.

# %% [markdown]
# Head to [dataportals.org](https://dataportals.org) to find a .csv file.
